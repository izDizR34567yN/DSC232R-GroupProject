# %%
# %%bash
#    export JAVA_OPTS="-Xmx8g"

# %%
# !java -XX:+PrintFlagsFinal -version
# Out:
# [Global flags]
#       int ActiveProcessorCount                     = -1                                        {product} {default}
#     uintx AdaptiveSizeDecrementScaleFactor         = 4                                         {product} {default}
#     uintx AdaptiveSizeMajorGCDecayTimeScale        = 10                                        {product} {default}
#     uintx AdaptiveSizePolicyCollectionCostMargin   = 50                                        {product} {default}
#     uintx AdaptiveSizePolicyInitializingSteps      = 20                                        {product} {default}
#     uintx AdaptiveSizePolicyOutputInterval         = 0                                         {product} {default}
#     uintx AdaptiveSizePolicyWeight                 = 10                                        {product} {default}
#     uintx AdaptiveSizeThroughPutPolicy             = 0                                         {product} {default}
#     uintx AdaptiveTimeWeight                       = 25                                        {product} {default}
#      bool AdjustStackSizeForTLS                    = false                                     {product} {default}
#      bool AggressiveHeap                           = false                                     {product} {default}
#      intx AliasLevel                               = 3                                      {C2 product} {default}
#      bool AlignVector                              = false                                  {C2 product} {default}
#     ccstr AllocateHeapAt                           =                                           {product} {default}
#      intx AllocateInstancePrefetchLines            = 1                                         {product} {default}
#      intx AllocatePrefetchDistance                 = 256                                       {product} {default}
#      intx AllocatePrefetchInstr                    = 0                                         {product} {default}
#      intx AllocatePrefetchLines                    = 3                                         {product} {default}
#      intx AllocatePrefetchStepSize                 = 64                                        {product} {default}
#      intx AllocatePrefetchStyle                    = 1                                         {product} {default}
#      bool AllowParallelDefineClass                 = false                                     {product} {default}
#      bool AllowRedefinitionToAddDeleteMethods      = false                                     {product} {default}
#      bool AllowUserSignalHandlers                  = false                                     {product} {default}
#      bool AllowVectorizeOnDemand                   = true                                   {C2 product} {default}
#      bool AlwaysActAsServerClassMachine            = false                                     {product} {default}
#      bool AlwaysCompileLoopMethods                 = false                                     {product} {default}
#      bool AlwaysLockClassLoader                    = false                                     {product} {default}
#      bool AlwaysPreTouch                           = false                                     {product} {default}
#      bool AlwaysRestoreFPU                         = false                                     {product} {default}
#      bool AlwaysTenure                             = false                                     {product} {default}
#     ccstr ArchiveClassesAtExit                     =                                           {product} {default}
#      intx ArrayCopyLoadStoreMaxElem                = 8                                      {C2 product} {default}
#    size_t AsyncLogBufferSize                       = 2097152                                   {product} {default}
#      intx AutoBoxCacheMax                          = 128                                    {C2 product} {default}
#      intx BCEATraceLevel                           = 0                                         {product} {default}
#      bool BackgroundCompilation                    = true                                   {pd product} {default}
#    size_t BaseFootPrintEstimate                    = 268435456                                 {product} {default}
#      intx BiasedLockingBulkRebiasThreshold         = 20                                        {product} {default}
#      intx BiasedLockingBulkRevokeThreshold         = 40                                        {product} {default}
#      intx BiasedLockingDecayTime                   = 25000                                     {product} {default}
#      intx BiasedLockingStartupDelay                = 0                                         {product} {default}
#      bool BlockLayoutByFrequency                   = true                                   {C2 product} {default}
#      intx BlockLayoutMinDiamondPercentage          = 20                                     {C2 product} {default}
#      bool BlockLayoutRotateLoops                   = true                                   {C2 product} {default}
#      intx C1InlineStackLimit                       = 5                                      {C1 product} {default}
#      intx C1MaxInlineLevel                         = 9                                      {C1 product} {default}
#      intx C1MaxInlineSize                          = 35                                     {C1 product} {default}
#      intx C1MaxRecursiveInlineLevel                = 1                                      {C1 product} {default}
#      intx C1MaxTrivialSize                         = 6                                      {C1 product} {default}
#      bool C1OptimizeVirtualCallProfiling           = true                                   {C1 product} {default}
#      bool C1ProfileBranches                        = true                                   {C1 product} {default}
#      bool C1ProfileCalls                           = true                                   {C1 product} {default}
#      bool C1ProfileCheckcasts                      = true                                   {C1 product} {default}
#      bool C1ProfileInlinedCalls                    = true                                   {C1 product} {default}
#      bool C1ProfileVirtualCalls                    = true                                   {C1 product} {default}
#      bool C1UpdateMethodData                       = true                                   {C1 product} {default}
#      intx CICompilerCount                          = 4                                         {product} {ergonomic}
#      bool CICompilerCountPerCPU                    = true                                      {product} {default}
#      bool CITime                                   = false                                     {product} {default}
#      bool CheckJNICalls                            = false                                     {product} {default}
#      bool ClassUnloading                           = true                                      {product} {default}
#      bool ClassUnloadingWithConcurrentMark         = true                                      {product} {default}
#      bool ClipInlining                             = true                                      {product} {default}
#     uintx CodeCacheExpansionSize                   = 65536                                  {pd product} {default}
#      bool CompactStrings                           = true                                   {pd product} {default}
#     ccstr CompilationMode                          = default                                   {product} {default}
# ccstrlist CompileCommand                           =                                           {product} {default}
#     ccstr CompileCommandFile                       =                                           {product} {default}
# ccstrlist CompileOnly                              =                                           {product} {default}
#      intx CompileThreshold                         = 10000                                  {pd product} {default}
#    double CompileThresholdScaling                  = 1.000000                                  {product} {default}
#      intx CompilerThreadPriority                   = -1                                        {product} {default}
#      intx CompilerThreadStackSize                  = 1024                                   {pd product} {default}
#    size_t CompressedClassSpaceSize                 = 1073741824                                {product} {default}
#      uint ConcGCThreads                            = 3                                         {product} {ergonomic}
#      intx ConditionalMoveLimit                     = 3                                   {C2 pd product} {default}
#      intx ContendedPaddingWidth                    = 128                                       {product} {default}
#      bool CrashOnOutOfMemoryError                  = false                                     {product} {default}
#      bool CreateCoredumpOnCrash                    = true                                      {product} {default}
#      bool CriticalJNINatives                       = false                                     {product} {default}
#      bool DTraceAllocProbes                        = false                                     {product} {default}
#      bool DTraceMethodProbes                       = false                                     {product} {default}
#      bool DTraceMonitorProbes                      = false                                     {product} {default}
#      bool DisableAttachMechanism                   = false                                     {product} {default}
#      bool DisableExplicitGC                        = false                                     {product} {default}
#      bool DisplayVMOutputToStderr                  = false                                     {product} {default}
#      bool DisplayVMOutputToStdout                  = false                                     {product} {default}
#      bool DoEscapeAnalysis                         = true                                   {C2 product} {default}
#      bool DoReserveCopyInSuperWord                 = true                                   {C2 product} {default}
#      bool DontCompileHugeMethods                   = true                                      {product} {default}
#      bool DontYieldALot                            = false                                  {pd product} {default}
#     ccstr DumpLoadedClassList                      =                                           {product} {default}
#      bool DumpReplayDataOnError                    = true                                      {product} {default}
#      bool DumpSharedSpaces                         = false                                     {product} {default}
#      bool DynamicDumpSharedSpaces                  = false                                     {product} {default}
#      bool EagerXrunInit                            = false                                     {product} {default}
#      intx EliminateAllocationArraySizeLimit        = 64                                     {C2 product} {default}
#      bool EliminateAllocations                     = true                                   {C2 product} {default}
#      bool EliminateAutoBox                         = true                                   {C2 product} {default}
#      bool EliminateLocks                           = true                                   {C2 product} {default}
#      bool EliminateNestedLocks                     = true                                   {C2 product} {default}
#      bool EnableContended                          = true                                      {product} {default}
#      bool EnableDynamicAgentLoading                = true                                      {product} {default}
#    size_t ErgoHeapSizeLimit                        = 0                                         {product} {default}
#     ccstr ErrorFile                                =                                           {product} {default}
#      bool ErrorFileToStderr                        = false                                     {product} {default}
#      bool ErrorFileToStdout                        = false                                     {product} {default}
#  uint64_t ErrorLogTimeout                          = 120                                       {product} {default}
#    double EscapeAnalysisTimeout                    = 20.000000                              {C2 product} {default}
#      bool EstimateArgEscape                        = true                                      {product} {default}
#      bool ExecutingUnitTests                       = false                                     {product} {default}
#      bool ExitOnOutOfMemoryError                   = false                                     {product} {default}
#      bool ExplicitGCInvokesConcurrent              = false                                     {product} {default}
#      bool ExtendedDTraceProbes                     = false                                     {product} {default}
#      bool ExtensiveErrorReports                    = false                                     {product} {default}
#     ccstr ExtraSharedClassListFile                 =                                           {product} {default}
#      bool FilterSpuriousWakeups                    = true                                      {product} {default}
#      bool FlightRecorder                           = false                                     {product} {default}
#     ccstr FlightRecorderOptions                    =                                           {product} {default}
#      bool ForceTimeHighResolution                  = false                                     {product} {default}
#      intx FreqInlineSize                           = 325                                 {C2 pd product} {default}
#    double G1ConcMarkStepDurationMillis             = 10.000000                                 {product} {default}
#     uintx G1ConcRSHotCardLimit                     = 4                                         {product} {default}
#    size_t G1ConcRSLogCacheSize                     = 10                                        {product} {default}
#    size_t G1ConcRefinementGreenZone                = 0                                         {product} {default}
#    size_t G1ConcRefinementRedZone                  = 0                                         {product} {default}
#     uintx G1ConcRefinementServiceIntervalMillis    = 300                                       {product} {default}
#      uint G1ConcRefinementThreads                  = 12                                        {product} {ergonomic}
#    size_t G1ConcRefinementThresholdStep            = 2                                         {product} {default}
#    size_t G1ConcRefinementYellowZone               = 0                                         {product} {default}
#     uintx G1ConfidencePercent                      = 50                                        {product} {default}
#    size_t G1HeapRegionSize                         = 16777216                                  {product} {ergonomic}
#     uintx G1HeapWastePercent                       = 5                                         {product} {default}
#     uintx G1MixedGCCountTarget                     = 8                                         {product} {default}
#     uintx G1PeriodicGCInterval                     = 0                                      {manageable} {default}
#      bool G1PeriodicGCInvokesConcurrent            = true                                      {product} {default}
#    double G1PeriodicGCSystemLoadThreshold          = 0.000000                               {manageable} {default}
#      intx G1RSetRegionEntries                      = 1280                                      {product} {default}
#      intx G1RSetSparseRegionEntries                = 128                                       {product} {default}
#      intx G1RSetUpdatingPauseTimePercent           = 10                                        {product} {default}
#      uint G1RefProcDrainInterval                   = 1000                                      {product} {default}
#     uintx G1ReservePercent                         = 10                                        {product} {default}
#     uintx G1SATBBufferEnqueueingThresholdPercent   = 60                                        {product} {default}
#    size_t G1SATBBufferSize                         = 1024                                      {product} {default}
#    size_t G1UpdateBufferSize                       = 256                                       {product} {default}
#      bool G1UseAdaptiveConcRefinement              = true                                      {product} {default}
#      bool G1UseAdaptiveIHOP                        = true                                      {product} {default}
#     uintx GCDrainStackTargetSize                   = 64                                        {product} {ergonomic}
#     uintx GCHeapFreeLimit                          = 2                                         {product} {default}
#     uintx GCLockerEdenExpansionPercent             = 5                                         {product} {default}
#     uintx GCPauseIntervalMillis                    = 201                                       {product} {default}
#     uintx GCTimeLimit                              = 98                                        {product} {default}
#     uintx GCTimeRatio                              = 12                                        {product} {default}
#    size_t HeapBaseMinAddress                       = 2147483648                             {pd product} {default}
#      bool HeapDumpAfterFullGC                      = false                                  {manageable} {default}
#      bool HeapDumpBeforeFullGC                     = false                                  {manageable} {default}
#      intx HeapDumpGzipLevel                        = 0                                      {manageable} {default}
#      bool HeapDumpOnOutOfMemoryError               = false                                  {manageable} {default}
#     ccstr HeapDumpPath                             =                                        {manageable} {default}
#     uintx HeapFirstMaximumCompactionCount          = 3                                         {product} {default}
#     uintx HeapMaximumCompactionInterval            = 20                                        {product} {default}
#     uintx HeapSearchSteps                          = 3                                         {product} {default}
#    size_t HeapSizePerGCThread                      = 43620760                                  {product} {default}
#      bool IgnoreEmptyClassPaths                    = false                                     {product} {default}
#      bool IgnoreUnrecognizedVMOptions              = false                                     {product} {default}
#     uintx IncreaseFirstTierCompileThresholdAt      = 50                                        {product} {default}
#      bool IncrementalInline                        = true                                   {C2 product} {default}
#     uintx InitialCodeCacheSize                     = 2555904                                {pd product} {default}
#    size_t InitialHeapSize                          = 2147483648                                {product} {ergonomic}
#     uintx InitialRAMFraction                       = 64                                        {product} {default}
#    double InitialRAMPercentage                     = 1.562500                                  {product} {default}
#     uintx InitialSurvivorRatio                     = 8                                         {product} {default}
#     uintx InitialTenuringThreshold                 = 7                                         {product} {default}
#     uintx InitiatingHeapOccupancyPercent           = 45                                        {product} {default}
#      bool Inline                                   = true                                      {product} {default}
#     ccstr InlineDataFile                           =                                           {product} {default}
#      intx InlineSmallCode                          = 2500                                {C2 pd product} {default}
#      bool InlineSynchronizedMethods                = true                                   {C1 product} {default}
#      intx InteriorEntryAlignment                   = 16                                  {C2 pd product} {default}
#      intx InterpreterProfilePercentage             = 33                                        {product} {default}
#      bool JavaMonitorsInStackTrace                 = true                                      {product} {default}
#      intx JavaPriority10_To_OSPriority             = -1                                        {product} {default}
#      intx JavaPriority1_To_OSPriority              = -1                                        {product} {default}
#      intx JavaPriority2_To_OSPriority              = -1                                        {product} {default}
#      intx JavaPriority3_To_OSPriority              = -1                                        {product} {default}
#      intx JavaPriority4_To_OSPriority              = -1                                        {product} {default}
#      intx JavaPriority5_To_OSPriority              = -1                                        {product} {default}
#      intx JavaPriority6_To_OSPriority              = -1                                        {product} {default}
#      intx JavaPriority7_To_OSPriority              = -1                                        {product} {default}
#      intx JavaPriority8_To_OSPriority              = -1                                        {product} {default}
#      intx JavaPriority9_To_OSPriority              = -1                                        {product} {default}
#    size_t LargePageHeapSizeThreshold               = 134217728                                 {product} {default}
#    size_t LargePageSizeInBytes                     = 0                                         {product} {default}
#      intx LiveNodeCountInliningCutoff              = 40000                                  {C2 product} {default}
#      bool LoadExecStackDllInVMThread               = true                                      {product} {default}
#      intx LoopMaxUnroll                            = 16                                     {C2 product} {default}
#      intx LoopOptsCount                            = 43                                     {C2 product} {default}
#      intx LoopPercentProfileLimit                  = 10                                  {C2 pd product} {default}
#     uintx LoopStripMiningIter                      = 1000                                   {C2 product} {default}
#     uintx LoopStripMiningIterShortLoop             = 100                                    {C2 product} {default}
#      intx LoopUnrollLimit                          = 60                                  {C2 pd product} {default}
#      intx LoopUnrollMin                            = 4                                      {C2 product} {default}
#      bool LoopUnswitching                          = true                                   {C2 product} {default}
#      bool ManagementServer                         = false                                     {product} {default}
#    size_t MarkStackSize                            = 4194304                                   {product} {ergonomic}
#    size_t MarkStackSizeMax                         = 536870912                                 {product} {default}
#      uint MarkSweepAlwaysCompactCount              = 4                                         {product} {default}
#     uintx MarkSweepDeadRatio                       = 5                                         {product} {default}
#      intx MaxBCEAEstimateLevel                     = 5                                         {product} {default}
#      intx MaxBCEAEstimateSize                      = 150                                       {product} {default}
#  uint64_t MaxDirectMemorySize                      = 0                                         {product} {default}
#      bool MaxFDLimit                               = true                                      {product} {default}
#     uintx MaxGCMinorPauseMillis                    = 18446744073709551615                      {product} {default}
#     uintx MaxGCPauseMillis                         = 200                                       {product} {default}
#     uintx MaxHeapFreeRatio                         = 70                                     {manageable} {default}
#    size_t MaxHeapSize                              = 32178700288                               {product} {ergonomic}
#      intx MaxInlineLevel                           = 15                                     {C2 product} {default}
#      intx MaxInlineSize                            = 35                                     {C2 product} {default}
#      intx MaxJNILocalCapacity                      = 65536                                     {product} {default}
#      intx MaxJavaStackTraceDepth                   = 1024                                      {product} {default}
#      intx MaxJumpTableSize                         = 65000                                  {C2 product} {default}
#      intx MaxJumpTableSparseness                   = 5                                      {C2 product} {default}
#      intx MaxLabelRootDepth                        = 1100                                   {C2 product} {default}
#      intx MaxLoopPad                               = 15                                     {C2 product} {default}
#    size_t MaxMetaspaceExpansion                    = 5439488                                   {product} {default}
#     uintx MaxMetaspaceFreeRatio                    = 70                                        {product} {default}
#    size_t MaxMetaspaceSize                         = 18446744073709551615                      {product} {default}
#    size_t MaxNewSize                               = 19293798400                               {product} {ergonomic}
#      intx MaxNodeLimit                             = 80000                                  {C2 product} {default}
#  uint64_t MaxRAM                                   = 137438953472                           {pd product} {default}
#     uintx MaxRAMFraction                           = 4                                         {product} {default}
#    double MaxRAMPercentage                         = 25.000000                                 {product} {default}
#      intx MaxRecursiveInlineLevel                  = 1                                      {C2 product} {default}
#     uintx MaxTenuringThreshold                     = 15                                        {product} {default}
#      intx MaxTrivialSize                           = 6                                      {C2 product} {default}
#      intx MaxVectorSize                            = 32                                     {C2 product} {default}
#     ccstr MetaspaceReclaimPolicy                   = balanced                                  {product} {default}
#    size_t MetaspaceSize                            = 22020096                                  {product} {default}
#      bool MethodFlushing                           = true                                      {product} {default}
#    size_t MinHeapDeltaBytes                        = 16777216                                  {product} {ergonomic}
#     uintx MinHeapFreeRatio                         = 40                                     {manageable} {default}
#    size_t MinHeapSize                              = 16777216                                  {product} {ergonomic}
#      intx MinInliningThreshold                     = 250                                       {product} {default}
#      intx MinJumpTableSize                         = 10                                  {C2 pd product} {default}
#    size_t MinMetaspaceExpansion                    = 327680                                    {product} {default}
#     uintx MinMetaspaceFreeRatio                    = 40                                        {product} {default}
#     uintx MinRAMFraction                           = 2                                         {product} {default}
#    double MinRAMPercentage                         = 50.000000                                 {product} {default}
#     uintx MinSurvivorRatio                         = 3                                         {product} {default}
#    size_t MinTLABSize                              = 2048                                      {product} {default}
#      intx MultiArrayExpandLimit                    = 6                                      {C2 product} {default}
#     uintx NUMAChunkResizeWeight                    = 20                                        {product} {default}
#    size_t NUMAInterleaveGranularity                = 2097152                                   {product} {default}
#     uintx NUMAPageScanRate                         = 256                                       {product} {default}
#    size_t NUMASpaceResizeRate                      = 1073741824                                {product} {default}
#      bool NUMAStats                                = false                                     {product} {default}
#     ccstr NativeMemoryTracking                     = off                                       {product} {default}
#      bool NeverActAsServerClassMachine             = false                                  {pd product} {default}
#      bool NeverTenure                              = false                                     {product} {default}
#     uintx NewRatio                                 = 2                                         {product} {default}
#    size_t NewSize                                  = 1363144                                   {product} {default}
#    size_t NewSizeThreadIncrease                    = 5320                                   {pd product} {default}
#      intx NmethodSweepActivity                     = 10                                        {product} {default}
#      intx NodeLimitFudgeFactor                     = 2000                                   {C2 product} {default}
#     uintx NonNMethodCodeHeapSize                   = 5839372                                {pd product} {ergonomic}
#     uintx NonProfiledCodeHeapSize                  = 122909434                              {pd product} {ergonomic}
#      intx NumberOfLoopInstrToAlign                 = 4                                      {C2 product} {default}
#      intx ObjectAlignmentInBytes                   = 8                              {product lp64_product} {default}
#    size_t OldPLABSize                              = 1024                                      {product} {default}
#    size_t OldSize                                  = 5452592                                   {product} {default}
#      bool OmitStackTraceInFastThrow                = true                                      {product} {default}
# ccstrlist OnError                                  =                                           {product} {default}
# ccstrlist OnOutOfMemoryError                       =                                           {product} {default}
#      intx OnStackReplacePercentage                 = 140                                    {pd product} {default}
#      bool OptimizeFill                             = false                                  {C2 product} {default}
#      bool OptimizePtrCompare                       = true                                   {C2 product} {default}
#      bool OptimizeStringConcat                     = true                                   {C2 product} {default}
#      bool OptoBundling                             = false                               {C2 pd product} {default}
#      intx OptoLoopAlignment                        = 16                                     {pd product} {default}
#      bool OptoRegScheduling                        = true                                {C2 pd product} {default}
#      bool OptoScheduling                           = false                               {C2 pd product} {default}
#     uintx PLABWeight                               = 75                                        {product} {default}
#      bool PSChunkLargeArrays                       = true                                      {product} {default}
#       int ParGCArrayScanChunk                      = 50                                        {product} {default}
#     uintx ParallelGCBufferWastePct                 = 10                                        {product} {default}
#      uint ParallelGCThreads                        = 12                                        {product} {default}
#    size_t ParallelOldDeadWoodLimiterMean           = 50                                        {product} {default}
#    size_t ParallelOldDeadWoodLimiterStdDev         = 80                                        {product} {default}
#      bool ParallelRefProcBalancingEnabled          = true                                      {product} {default}
#      bool ParallelRefProcEnabled                   = true                                      {product} {default}
#      bool PartialPeelAtUnsignedTests               = true                                   {C2 product} {default}
#      bool PartialPeelLoop                          = true                                   {C2 product} {default}
#      intx PartialPeelNewPhiDelta                   = 0                                      {C2 product} {default}
#     uintx PausePadding                             = 1                                         {product} {default}
#      intx PerBytecodeRecompilationCutoff           = 200                                       {product} {default}
#      intx PerBytecodeTrapLimit                     = 4                                         {product} {default}
#      intx PerMethodRecompilationCutoff             = 400                                       {product} {default}
#      intx PerMethodTrapLimit                       = 100                                       {product} {default}
#      bool PerfAllowAtExitRegistration              = false                                     {product} {default}
#      bool PerfBypassFileSystemCheck                = false                                     {product} {default}
#      intx PerfDataMemorySize                       = 32768                                     {product} {default}
#      intx PerfDataSamplingInterval                 = 50                                        {product} {default}
#     ccstr PerfDataSaveFile                         =                                           {product} {default}
#      bool PerfDataSaveToFile                       = false                                     {product} {default}
#      bool PerfDisableSharedMem                     = false                                     {product} {default}
#      intx PerfMaxStringConstLength                 = 1024                                      {product} {default}
#    size_t PreTouchParallelChunkSize                = 4194304                                {pd product} {default}
#      bool PreferContainerQuotaForCPUCount          = true                                      {product} {default}
#      bool PreferInterpreterNativeStubs             = false                                  {pd product} {default}
#      intx PrefetchCopyIntervalInBytes              = 576                                       {product} {default}
#      intx PrefetchFieldsAhead                      = 1                                         {product} {default}
#      intx PrefetchScanIntervalInBytes              = 576                                       {product} {default}
#      bool PreserveAllAnnotations                   = false                                     {product} {default}
#      bool PreserveFramePointer                     = false                                  {pd product} {default}
#    size_t PretenureSizeThreshold                   = 0                                         {product} {default}
#      bool PrintClassHistogram                      = false                                  {manageable} {default}
#      bool PrintCodeCache                           = false                                     {product} {default}
#      bool PrintCodeCacheOnCompilation              = false                                     {product} {default}
#      bool PrintCommandLineFlags                    = false                                     {product} {default}
#      bool PrintCompilation                         = false                                     {product} {default}
#      bool PrintConcurrentLocks                     = false                                  {manageable} {default}
#      bool PrintExtendedThreadInfo                  = false                                     {product} {default}
#      bool PrintFlagsFinal                          = true                                      {product} {command line}
#      bool PrintFlagsInitial                        = false                                     {product} {default}
#      bool PrintFlagsRanges                         = false                                     {product} {default}
#      bool PrintGC                                  = false                                     {product} {default}
#      bool PrintGCDetails                           = false                                     {product} {default}
#      bool PrintHeapAtSIGBREAK                      = true                                      {product} {default}
#      bool PrintSharedArchiveAndExit                = false                                     {product} {default}
#      bool PrintSharedDictionary                    = false                                     {product} {default}
#      bool PrintStringTableStatistics               = false                                     {product} {default}
#      bool PrintTieredEvents                        = false                                     {product} {default}
#      bool PrintVMOptions                           = false                                     {product} {default}
#      bool PrintWarnings                            = true                                      {product} {default}
#     uintx ProcessDistributionStride                = 4                                         {product} {default}
#      bool ProfileInterpreter                       = true                                   {pd product} {default}
#      intx ProfileMaturityPercentage                = 20                                        {product} {default}
#     uintx ProfiledCodeHeapSize                     = 122909434                              {pd product} {ergonomic}
#     uintx PromotedPadding                          = 3                                         {product} {default}
#     uintx QueuedAllocationWarningCount             = 0                                         {product} {default}
#       int RTMRetryCount                            = 5                                    {ARCH product} {default}
#      bool RangeCheckElimination                    = true                                      {product} {default}
#      bool ReassociateInvariants                    = true                                   {C2 product} {default}
#      bool RecordDynamicDumpInfo                    = false                                     {product} {default}
#      bool ReduceBulkZeroing                        = true                                   {C2 product} {default}
#      bool ReduceFieldZeroing                       = true                                   {C2 product} {default}
#      bool ReduceInitialCardMarks                   = true                                   {C2 product} {default}
#      bool ReduceSignalUsage                        = false                                     {product} {default}
#      intx RefDiscoveryPolicy                       = 0                                         {product} {default}
#      bool RegisterFinalizersAtInit                 = true                                      {product} {default}
#      bool RelaxAccessControlCheck                  = false                                     {product} {default}
#     ccstr ReplayDataFile                           =                                           {product} {default}
#      bool RequireSharedSpaces                      = false                                     {product} {default}
#     uintx ReservedCodeCacheSize                    = 251658240                              {pd product} {ergonomic}
#      bool ResizePLAB                               = true                                      {product} {default}
#      bool ResizeTLAB                               = true                                      {product} {default}
#      bool RestoreMXCSROnJNICalls                   = false                                     {product} {default}
#      bool RestrictContended                        = true                                      {product} {default}
#      bool RestrictReservedStack                    = true                                      {product} {default}
#      bool RewriteBytecodes                         = true                                   {pd product} {default}
#      bool RewriteFrequentPairs                     = true                                   {pd product} {default}
#      bool SafepointTimeout                         = false                                     {product} {default}
#      intx SafepointTimeoutDelay                    = 10000                                     {product} {default}
#      bool ScavengeBeforeFullGC                     = false                                     {product} {default}
#      bool SegmentedCodeCache                       = true                                      {product} {ergonomic}
#      intx SelfDestructTimer                        = 0                                         {product} {default}
#     ccstr SharedArchiveConfigFile                  =                                           {product} {default}
#     ccstr SharedArchiveFile                        =                                           {product} {default}
#    size_t SharedBaseAddress                        = 23453054795776                            {product} {default}
#     ccstr SharedClassListFile                      =                                           {product} {default}
#     uintx SharedSymbolTableBucketSize              = 4                                         {product} {default}
#     ccstr ShenandoahGCHeuristics                   = adaptive                                  {product} {default}
#     ccstr ShenandoahGCMode                         = satb                                      {product} {default}
#      bool ShowCodeDetailsInExceptionMessages       = true                                   {manageable} {default}
#      bool ShowMessageBoxOnError                    = false                                     {product} {default}
#      bool ShrinkHeapInSteps                        = true                                      {product} {default}
#    size_t SoftMaxHeapSize                          = 32178700288                            {manageable} {ergonomic}
#      intx SoftRefLRUPolicyMSPerMB                  = 1000                                      {product} {default}
#      bool SplitIfBlocks                            = true                                   {C2 product} {default}
#      intx StackRedPages                            = 1                                      {pd product} {default}
#      intx StackReservedPages                       = 1                                      {pd product} {default}
#      intx StackShadowPages                         = 20                                     {pd product} {default}
#      bool StackTraceInThrowable                    = true                                      {product} {default}
#      intx StackYellowPages                         = 2                                      {pd product} {default}
#     uintx StartAggressiveSweepingAt                = 10                                        {product} {default}
#      bool StartAttachListener                      = false                                     {product} {default}
#     ccstr StartFlightRecording                     =                                           {product} {default}
#      uint StringDeduplicationAgeThreshold          = 3                                         {product} {default}
#     uintx StringTableSize                          = 65536                                     {product} {default}
#      bool SuperWordLoopUnrollAnalysis              = true                                {C2 pd product} {default}
#      bool SuperWordReductions                      = true                                   {C2 product} {default}
#      bool SuppressFatalErrorMessage                = false                                     {product} {default}
#     uintx SurvivorPadding                          = 3                                         {product} {default}
#     uintx SurvivorRatio                            = 8                                         {product} {default}
#    double SweeperThreshold                         = 0.500000                                  {product} {default}
#     uintx TLABAllocationWeight                     = 35                                        {product} {default}
#     uintx TLABRefillWasteFraction                  = 64                                        {product} {default}
#    size_t TLABSize                                 = 0                                         {product} {default}
#      bool TLABStats                                = true                                      {product} {default}
#     uintx TLABWasteIncrement                       = 4                                         {product} {default}
#     uintx TLABWasteTargetPercent                   = 1                                         {product} {default}
#     uintx TargetPLABWastePct                       = 10                                        {product} {default}
#     uintx TargetSurvivorRatio                      = 50                                        {product} {default}
#     uintx TenuredGenerationSizeIncrement           = 20                                        {product} {default}
#     uintx TenuredGenerationSizeSupplement          = 80                                        {product} {default}
#     uintx TenuredGenerationSizeSupplementDecay     = 2                                         {product} {default}
#      intx ThreadPriorityPolicy                     = 0                                         {product} {default}
#      bool ThreadPriorityVerbose                    = false                                     {product} {default}
#      intx ThreadStackSize                          = 1024                                   {pd product} {default}
#     uintx ThresholdTolerance                       = 10                                        {product} {default}
#      intx Tier0BackedgeNotifyFreqLog               = 10                                        {product} {default}
#      intx Tier0InvokeNotifyFreqLog                 = 7                                         {product} {default}
#      intx Tier0ProfilingStartPercentage            = 200                                       {product} {default}
#      intx Tier23InlineeNotifyFreqLog               = 20                                        {product} {default}
#      intx Tier2BackEdgeThreshold                   = 0                                         {product} {default}
#      intx Tier2BackedgeNotifyFreqLog               = 14                                        {product} {default}
# ...
#      intx Tier3DelayOff                            = 2                                         {product} {default}
#      intx Tier3DelayOn                             = 5                                         {product} {default}
#      intx Tier3InvocationThreshold                 = 200                                       {product} {default}
#      intx Tier3InvokeNotifyFreqLog                 = 10                                        {product} {default}
#      intx Tier3LoadFeedback                        = 5                                         {product} {default}
#      intx Tier3MinInvocationThreshold              = 100                                       {product} {default}
#      intx Tier4BackEdgeThreshold                   = 40000                                     {product} {default}
#      intx Tier4CompileThreshold                    = 15000                                     {product} {default}
#      intx Tier4InvocationThreshold                 = 5000                                      {product} {default}
#      intx Tier4LoadFeedback                        = 3                                         {product} {default}
#      intx Tier4MinInvocationThreshold              = 600                                       {product} {default}
#      bool TieredCompilation                        = true                                   {pd product} {default}
#      intx TieredCompileTaskTimeout                 = 50                                        {product} {default}
#      intx TieredRateUpdateMaxTime                  = 25                                        {product} {default}
#      intx TieredRateUpdateMinTime                  = 1                                         {product} {default}
#      intx TieredStopAtLevel                        = 4                                         {product} {default}
#      bool TimeLinearScan                           = false                                  {C1 product} {default}
#     ccstr TraceJVMTI                               =                                           {product} {default}
#      intx TrackedInitializationLimit               = 50                                     {C2 product} {default}
#      bool TrapBasedNullChecks                      = false                                  {pd product} {default}
#      bool TrapBasedRangeChecks                     = false                               {C2 pd product} {default}
#      intx TypeProfileArgsLimit                     = 2                                         {product} {default}
#     uintx TypeProfileLevel                         = 111                                    {pd product} {default}
#      intx TypeProfileMajorReceiverPercent          = 90                                     {C2 product} {default}
#      intx TypeProfileParmsLimit                    = 2                                         {product} {default}
#      intx TypeProfileWidth                         = 2                                         {product} {default}
#      intx UnguardOnExecutionViolation              = 0                                         {product} {default}
#      bool UseAES                                   = true                                      {product} {default}
#      intx UseAVX                                   = 2                                    {ARCH product} {default}
#      bool UseAdaptiveGenerationSizePolicyAtMajorCollection  = true                             {product} {default}
#      bool UseAdaptiveGenerationSizePolicyAtMinorCollection  = true                             {product} {default}
#      bool UseAdaptiveNUMAChunkSizing               = true                                      {product} {default}
#      bool UseAdaptiveSizeDecayMajorGCCost          = true                                      {product} {default}
#      bool UseAdaptiveSizePolicy                    = true                                      {product} {default}
#      bool UseAdaptiveSizePolicyFootprintGoal       = true                                      {product} {default}
#      bool UseAdaptiveSizePolicyWithSystemGC        = false                                     {product} {default}
#      bool UseAddressNop                            = true                                 {ARCH product} {default}
#      bool UseBASE64Intrinsics                      = false                                     {product} {default}
#      bool UseBMI1Instructions                      = true                                 {ARCH product} {default}
#      bool UseBMI2Instructions                      = true                                 {ARCH product} {default}
#      bool UseBiasedLocking                         = false                                     {product} {default}
#      bool UseBimorphicInlining                     = true                                   {C2 product} {default}
#      bool UseCLMUL                                 = true                                 {ARCH product} {default}
#      bool UseCMoveUnconditionally                  = false                                  {C2 product} {default}
#      bool UseCodeAging                             = true                                      {product} {default}
#      bool UseCodeCacheFlushing                     = true                                      {product} {default}
#      bool UseCompiler                              = true                                      {product} {default}
#      bool UseCompressedClassPointers               = true                           {product lp64_product} {ergonomic}
#      bool UseCompressedOops                        = true                           {product lp64_product} {ergonomic}
#      bool UseCondCardMark                          = false                                     {product} {default}
#      bool UseContainerCpuShares                    = false                                     {product} {default}
#      bool UseContainerSupport                      = true                                      {product} {default}
#      bool UseCountLeadingZerosInstruction          = true                                 {ARCH product} {default}
#      bool UseCountTrailingZerosInstruction         = true                                 {ARCH product} {default}
#      bool UseCountedLoopSafepoints                 = true                                   {C2 product} {default}
#      bool UseCounterDecay                          = true                                      {product} {default}
#      bool UseDivMod                                = true                                   {C2 product} {default}
#      bool UseDynamicNumberOfCompilerThreads        = true                                      {product} {default}
#      bool UseDynamicNumberOfGCThreads              = true                                      {product} {default}
#      bool UseEmptySlotsInSupers                    = true                                      {product} {default}
#      bool UseFMA                                   = true                                      {product} {default}
#      bool UseFPUForSpilling                        = true                                   {C2 product} {default}
#      bool UseFastJNIAccessors                      = true                                      {product} {default}
#      bool UseFastStosb                             = false                                {ARCH product} {default}
#      bool UseG1GC                                  = true                                      {product} {ergonomic}
#      bool UseGCOverheadLimit                       = true                                      {product} {default}
#      bool UseHeavyMonitors                         = false                                     {product} {default}
#      bool UseHugeTLBFS                             = false                                     {product} {default}
#      bool UseInlineCaches                          = true                                      {product} {default}
#      bool UseInterpreter                           = true                                      {product} {default}
#      bool UseJumpTables                            = true                                   {C2 product} {default}
#      bool UseLargePages                            = false                                  {pd product} {default}
#      bool UseLargePagesIndividualAllocation        = false                                  {pd product} {default}
#      bool UseLinuxPosixThreadCPUClocks             = true                                      {product} {default}
#      bool UseLoopCounter                           = true                                      {product} {default}
#      bool UseLoopInvariantCodeMotion               = true                                   {C1 product} {default}
#      bool UseLoopPredicate                         = true                                   {C2 product} {default}
#      bool UseMaximumCompactionOnSystemGC           = true                                      {product} {default}
#      bool UseNUMA                                  = false                                     {product} {default}
#      bool UseNUMAInterleaving                      = false                                     {product} {default}
#      bool UseNewLongLShift                         = true                                 {ARCH product} {default}
#      bool UseNotificationThread                    = true                                      {product} {default}
#      bool UseOnStackReplacement                    = true                                   {pd product} {default}
#      bool UseOnlyInlinedBimorphic                  = true                                   {C2 product} {default}
#      bool UseOprofile                              = false                                     {product} {default}
#      bool UseOptoBiasInlining                      = false                                  {C2 product} {default}
#      bool UsePSAdaptiveSurvivorSizePolicy          = true                                      {product} {default}
#      bool UseParallelGC                            = false                                     {product} {default}
#      bool UsePerfData                              = true                                      {product} {default}
#      bool UsePopCountInstruction                   = true                                      {product} {default}
#      bool UseProfiledLoopPredicate                 = true                                   {C2 product} {default}
#      bool UseRTMDeopt                              = false                                {ARCH product} {default}
#      bool UseRTMLocking                            = false                                {ARCH product} {default}
#      bool UseSHA                                   = true                                      {product} {default}
#      bool UseSHM                                   = false                                     {product} {default}
#      intx UseSSE                                   = 4                                    {ARCH product} {default}
#      bool UseSSE42Intrinsics                       = true                                 {ARCH product} {default}
#      bool UseSerialGC                              = false                                     {product} {default}
#      bool UseSharedSpaces                          = true                                      {product} {default}
#      bool UseShenandoahGC                          = false                                     {product} {default}
#      bool UseSignalChaining                        = true                                      {product} {default}
#      bool UseStoreImmI16                           = true                                 {ARCH product} {default}
#      bool UseStringDeduplication                   = false                                     {product} {default}
#      bool UseSubwordForMaxVector                   = true                                   {C2 product} {default}
#      bool UseSuperWord                             = true                                   {C2 product} {default}
#      bool UseTLAB                                  = true                                      {product} {default}
#      bool UseThreadPriorities                      = true                                   {pd product} {default}
#      bool UseTransparentHugePages                  = false                                     {product} {default}
#      bool UseTypeProfile                           = true                                      {product} {default}
#      bool UseTypeSpeculation                       = true                                   {C2 product} {default}
#      bool UseUnalignedLoadStores                   = true                                 {ARCH product} {default}
#      bool UseVectorCmov                            = false                                  {C2 product} {default}
#      bool UseXMMForArrayCopy                       = true                                      {product} {default}
#      bool UseXMMForObjInit                         = true                                 {ARCH product} {default}
#      bool UseXmmI2D                                = true                                 {ARCH product} {default}
#      bool UseXmmI2F                                = true                                 {ARCH product} {default}
#      bool UseXmmLoadAndClearUpper                  = true                                 {ARCH product} {default}
#      bool UseXmmRegToRegMoveAll                    = true                                 {ARCH product} {default}
#      bool UseZGC                                   = false                                     {product} {default}
#      intx VMThreadPriority                         = -1                                        {product} {default}
#      intx VMThreadStackSize                        = 1024                                   {pd product} {default}
#      intx ValueMapInitialSize                      = 11                                     {C1 product} {default}
#      intx ValueMapMaxLoopSize                      = 8                                      {C1 product} {default}
#      intx ValueSearchLimit                         = 1000                                   {C2 product} {default}
#      bool VerifySharedSpaces                       = false                                     {product} {default}
#     uintx YoungGenerationSizeIncrement             = 20                                        {product} {default}
#     uintx YoungGenerationSizeSupplement            = 80                                        {product} {default}
#     uintx YoungGenerationSizeSupplementDecay       = 8                                         {product} {default}
#    size_t YoungPLABSize                            = 4096                                      {product} {default}
#    double ZAllocationSpikeTolerance                = 2.000000                                  {product} {default}
#    double ZCollectionInterval                      = 0.000000                                  {product} {default}
#    double ZFragmentationLimit                      = 25.000000                                 {product} {default}
#    size_t ZMarkStackSpaceLimit                     = 8589934592                                {product} {default}
#      bool ZProactive                               = true                                      {product} {default}
#      bool ZUncommit                                = true                                      {product} {default}
#     uintx ZUncommitDelay                           = 300                                       {product} {default}
#      bool ZeroTLAB                                 = false                                     {product} {default}
# openjdk version "17.0.8.1" 2023-08-24
# OpenJDK Runtime Environment (build 17.0.8.1+1-Ubuntu-0ubuntu122.04)
# OpenJDK 64-Bit Server VM (build 17.0.8.1+1-Ubuntu-0ubuntu122.04, mixed mode, sharing)

# %%
# !pip install kaggle
# !kaggle datasets download -d sunnykakar/spotify-charts-all-audio-data
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kaggle in /home/seltawil/.local/lib/python3.11/site-packages (1.6.12)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.11/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /opt/conda/lib/python3.11/site-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.11/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /home/seltawil/.local/lib/python3.11/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.11/site-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.11/site-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/seltawil/.local/lib/python3.11/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->kaggle) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->kaggle) (3.4)
# /bin/bash: line 1: kaggle: command not found

# %%
# !unzip spotify-charts-all-audio-data.zip
# Out:
# unzip:  cannot find or open spotify-charts-all-audio-data.zip, spotify-charts-all-audio-data.zip.zip or spotify-charts-all-audio-data.zip.ZIP.

# %%
# !pip install pyspark
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyspark in /usr/local/spark/python (3.5.0)
# Requirement already satisfied: py4j==0.10.9.7 in /home/seltawil/.local/lib/python3.11/site-packages (from pyspark) (0.10.9.7)

# %%
from pyspark import SparkContext
from pyspark.sql import SQLContext
sc = SparkContext()
sqlContext = SQLContext(sc)
# Out:
# /usr/local/spark/python/pyspark/sql/context.py:113: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Preliminary Exploration

# %%
# Inspect schema of an initial load of the data.

data_path = 'spotify-charts-all-audio-data/merged_data.csv'

try:
    rawload = sqlContext.read.csv(data_path, header = True)
    rawload.printSchema()
except Exception:
    print(f'Error loading "{data_path}".')
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- rank: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- artist: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- chart: string (nullable = true)
#  |-- trend: string (nullable = true)
#  |-- streams: string (nullable = true)
#  |-- track_id: string (nullable = true)
#  |-- album: string (nullable = true)
#  |-- popularity: string (nullable = true)
#  |-- duration_ms: string (nullable = true)
#  |-- explicit: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- available_markets: string (nullable = true)
#  |-- af_danceability: string (nullable = true)
#  |-- af_energy: string (nullable = true)
#  |-- af_key: string (nullable = true)
#  |-- af_loudness: string (nullable = true)
#  |-- af_mode: string (nullable = true)
#  |-- af_speechiness: string (nullable = true)
#  |-- af_acousticness: string (nullable = true)
#  |-- af_instrumentalness: string (nullable = true)
#  |-- af_liveness: string (nullable = true)
#  |-- af_valence: string (nullable = true)
#  |-- af_tempo: string (nullable = true)
#  |-- af_time_signature: string (nullable = true)

# %%
# Show the first 5 rows of raw data
rawload.head(5)
# Out:
# [Row(_c0='0', title='Chantaje (feat. Maluma)', rank='1', date='2017-01-01', artist='Shakira', url='https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg', region='Argentina', chart='top200', trend='SAME_POSITION', streams='253019.0', track_id='6mICuAdrwEjh6Y6lroV2Kg', album='El Dorado', popularity='78.0', duration_ms='195840.0', explicit='False', release_date='2017-05-26', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability='0.852', af_energy='0.773', af_key='8.0', af_loudness='-2.921', af_mode='0.0', af_speechiness='0.0776', af_acousticness='0.187', af_instrumentalness='3.05e-05', af_liveness='0.159', af_valence='0.907', af_tempo='102.034', af_time_signature='4.0'),
#  Row(_c0='1', title="Vente Pa' Ca (feat. Maluma)", rank='2', date='2017-01-01', artist='Ricky Martin', url='https://open.spotify.com/track/7DM4BPaS7uofFul3ywMe46', region='Argentina', chart='top200', trend='MOVE_UP', streams='223988.0', track_id='7DM4BPaS7uofFul3ywMe46', album="Vente Pa' Ca (feat. Maluma)", popularity='72.0', duration_ms='259195.0', explicit='False', release_date='2016-09-22', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability='0.663', af_energy='0.92', af_key='11.0', af_loudness='-4.07', af_mode='0.0', af_speechiness='0.226', af_acousticness='0.00431', af_instrumentalness='1.69e-05', af_liveness='0.101', af_valence='0.533', af_tempo='99.935', af_time_signature='4.0'),
#  Row(_c0='2', title='Reggaetón Lento (Bailemos)', rank='3', date='2017-01-01', artist='CNCO', url='https://open.spotify.com/track/3AEZUABDXNtecAOSC1qTfo', region='Argentina', chart='top200', trend='MOVE_DOWN', streams='210943.0', track_id='3AEZUABDXNtecAOSC1qTfo', album='Primera Cita', popularity='73.0', duration_ms='222560.0', explicit='False', release_date='2016-08-26', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability='0.761', af_energy='0.838', af_key='4.0', af_loudness='-3.073', af_mode='0.0', af_speechiness='0.0502', af_acousticness='0.4', af_instrumentalness='0.0', af_liveness='0.176', af_valence='0.71', af_tempo='93.974', af_time_signature='4.0'),
#  Row(_c0='3', title='Safari', rank='4', date='2017-01-01', artist='J Balvin, Pharrell Williams, BIA, Sky', url='https://open.spotify.com/track/6rQSrBHf7HlZjtcMZ4S4bO', region='Argentina', chart='top200', trend='SAME_POSITION', streams='173865.0', track_id='6rQSrBHf7HlZjtcMZ4S4bO', album='Energía', popularity='0.0', duration_ms='205600.0', explicit='False', release_date='2016-06-24', available_markets='[]', af_danceability='0.508', af_energy='0.687', af_key='0.0', af_loudness='-4.361', af_mode='1.0', af_speechiness='0.326', af_acousticness='0.551', af_instrumentalness='3.41e-06', af_liveness='0.126', af_valence='0.555', af_tempo='180.044', af_time_signature='4.0'),
#  Row(_c0='4', title='Shaky Shaky', rank='5', date='2017-01-01', artist='Daddy Yankee', url='https://open.spotify.com/track/58IL315gMSTD37DOZPJ2hf', region='Argentina', chart='top200', trend='MOVE_UP', streams='153956.0', track_id='58IL315gMSTD37DOZPJ2hf', album='Shaky Shaky', popularity='0.0', duration_ms='234320.0', explicit='False', release_date='2016-04-08', available_markets='[]', af_danceability='0.899', af_energy='0.626', af_key='6.0', af_loudness='-4.228', af_mode='0.0', af_speechiness='0.292', af_acousticness='0.076', af_instrumentalness='0.0', af_liveness='0.0631', af_valence='0.873', af_tempo='88.007', af_time_signature='4.0')]

# %%
# Rename the first column, which refers to a primary key that was blandly named '_c0' by default.

df = rawload.withColumnRenamed('_c0', 'ID')

# %%
# Count observations in the dataset.

df_ct = df.count()
print(f'There are {df_ct} observations in this dataset.')
# Out:
# There are 26174269 observations in this dataset.

# %% [markdown]
# ## Getting Summary Statistics for Numeric Attributes

# %%
# As the above schema shows, all attributes assume the string type, even though many of them are numeric. View a
# single observation to determine which attributes are numeric.

print(f'SAMPLE OBSERVATION:\n\n{df.take(1)}')
# Out:
# SAMPLE OBSERVATION:
#
# [Row(ID='0', title='Chantaje (feat. Maluma)', rank='1', date='2017-01-01', artist='Shakira', url='https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg', region='Argentina', chart='top200', trend='SAME_POSITION', streams='253019.0', track_id='6mICuAdrwEjh6Y6lroV2Kg', album='El Dorado', popularity='78.0', duration_ms='195840.0', explicit='False', release_date='2017-05-26', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability='0.852', af_energy='0.773', af_key='8.0', af_loudness='-2.921', af_mode='0.0', af_speechiness='0.0776', af_acousticness='0.187', af_instrumentalness='3.05e-05', af_liveness='0.159', af_valence='0.907', af_tempo='102.034', af_time_signature='4.0')]

# %%
# Evaluating the above observation allows us to establish which attributes are numeric.

numeric_attributes = ['ID', 'rank', 'streams', 'popularity', 'duration_ms', 'af_danceability', 'af_energy',
                      'af_key', 'af_loudness', 'af_mode', 'af_speechiness', 'af_acousticness',
                      'af_instrumentalness', 'af_liveness', 'af_valence', 'af_tempo',  'af_time_signature']
df[numeric_attributes].show(5)
# Out:
# +---+----+--------+----------+-----------+---------------+---------+------+-----------+-------+--------------+---------------+-------------------+-----------+----------+--------+-----------------+
# | ID|rank| streams|popularity|duration_ms|af_danceability|af_energy|af_key|af_loudness|af_mode|af_speechiness|af_acousticness|af_instrumentalness|af_liveness|af_valence|af_tempo|af_time_signature|
# +---+----+--------+----------+-----------+---------------+---------+------+-----------+-------+--------------+---------------+-------------------+-----------+----------+--------+-----------------+
# |  0|   1|253019.0|      78.0|   195840.0|          0.852|    0.773|   8.0|     -2.921|    0.0|        0.0776|          0.187|           3.05e-05|      0.159|     0.907| 102.034|              4.0|
# |  1|   2|223988.0|      72.0|   259195.0|          0.663|     0.92|  11.0|      -4.07|    0.0|         0.226|        0.00431|           1.69e-05|      0.101|     0.533|  99.935|              4.0|
# |  2|   3|210943.0|      73.0|   222560.0|          0.761|    0.838|   4.0|     -3.073|    0.0|        0.0502|            0.4|                0.0|      0.176|      0.71|  93.974|              4.0|
# |  3|   4|173865.0|       0.0|   205600.0|          0.508|    0.687|   0.0|     -4.361|    1.0|         0.326|          0.551|           3.41e-06|      0.126|     0.555| 180.044|              4.0|
# |  4|   5|153956.0|       0.0|   234320.0|          0.899|    0.626|   6.0|     -4.228|    0.0|         0.292|          0.076|                0.0|     0.0631|     0.873|  88.007|              4.0|
# +---+----+--------+----------+-----------+---------------+---------+------+-----------+-------+--------------+---------------+-------------------+-----------+----------+--------+-----------------+
# only showing top 5 rows

# %%
# We'll have to cast numeric attributes to floats to explore these attributes.

df = df.withColumns(dict(zip(numeric_attributes, [df[attribute].cast('float') for attribute in
                                                  numeric_attributes])))

# %%
# Confirm that type casting was correctly implemented.

print('UPDATED SCHEMA:\n')
df.printSchema()
print(f'\n\nSAMPLE OBSERVATION:\n\n{df.take(1)}')
# Out:
# UPDATED SCHEMA:
#
# root
#  |-- ID: float (nullable = true)
#  |-- title: string (nullable = true)
#  |-- rank: float (nullable = true)
#  |-- date: string (nullable = true)
#  |-- artist: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- chart: string (nullable = true)
#  |-- trend: string (nullable = true)
#  |-- streams: float (nullable = true)
#  |-- track_id: string (nullable = true)
#  |-- album: string (nullable = true)
#  |-- popularity: float (nullable = true)
#  |-- duration_ms: float (nullable = true)
#  |-- explicit: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- available_markets: string (nullable = true)
#  |-- af_danceability: float (nullable = true)
#  |-- af_energy: float (nullable = true)
#  |-- af_key: float (nullable = true)
#  |-- af_loudness: float (nullable = true)
#  |-- af_mode: float (nullable = true)
#  |-- af_speechiness: float (nullable = true)
#  |-- af_acousticness: float (nullable = true)
#  |-- af_instrumentalness: float (nullable = true)
#  |-- af_liveness: float (nullable = true)
#  |-- af_valence: float (nullable = true)
#  |-- af_tempo: float (nullable = true)
#  |-- af_time_signature: float (nullable = true)
#
#
#
# SAMPLE OBSERVATION:
#
# [Row(ID=0.0, title='Chantaje (feat. Maluma)', rank=1.0, date='2017-01-01', artist='Shakira', url='https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg', region='Argentina', chart='top200', trend='SAME_POSITION', streams=253019.0, track_id='6mICuAdrwEjh6Y6lroV2Kg', album='El Dorado', popularity=78.0, duration_ms=195840.0, explicit='False', release_date='2017-05-26', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability=0.8519999980926514, af_energy=0.7730000019073486, af_key=8.0, af_loudness=-2.9210000038146973, af_mode=0.0, af_speechiness=0.07760000228881836, af_acousticness=0.18700000643730164, af_instrumentalness=3.0499999411404133e-05, af_liveness=0.1589999943971634, af_valence=0.9070000052452087, af_tempo=102.03399658203125, af_time_signature=4.0)]

# %%
# Now that we've casted numeric attributes to floats, we can generate summary statistics for them.

nas = df[numeric_attributes].describe()

# %%
# We can display summary statistics in a visually appealing format by implementing the following.

for attribute in numeric_attributes:
    nas[['summary', attribute]].show()
# Out:
# +-------+-----------------+
# |summary|               ID|
# +-------+-----------------+
# |  count|         26174269|
# |   mean|      1.3087134E7|
# | stddev|7555860.770833806|
# |    min|              0.0|
# |    max|      2.6174268E7|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|              rank|
# +-------+------------------+
# |  count|          26172127|
# |   mean|  80.9233979339929|
# | stddev|59.185732716119134|
# |    min|               1.0|
# |    max|             200.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|           streams|
# +-------+------------------+
# |  count|          20318240|
# |   mean|55266.480036705936|
# | stddev|209601.75006362287|
# |    min|            1001.0|
# |    max|       1.9749704E7|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|       popularity|
# +-------+-----------------+
# |  count|         25853279|
# |   mean|46.71695659958646|
# | stddev|32.81488206233617|
# |    min|              0.0|
# |    max|          19176.0|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|       duration_ms|
# +-------+------------------+
# |  count|          25867502|
# |   mean|209123.03448782954|
# | stddev|51667.759052543384|
# |    min|               0.0|
# |    max|         9318296.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|   af_danceability|
# +-------+------------------+
# |  count|          25853466|
# |   mean|2.0595610216256315|
# | stddev| 526.1438147899456|
# |    min|               0.0|
# |    max|          201655.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         af_energy|
# +-------+------------------+
# |  count|          25867615|
# |   mean|1.2516711805628786|
# | stddev| 517.2946346368159|
# |    min|               0.0|
# |    max|          443404.0|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|           af_key|
# +-------+-----------------+
# |  count|         25869755|
# |   mean|6.269610899260092|
# | stddev|542.9296515249761|
# |    min|              0.0|
# |    max|         314697.0|
# +-------+-----------------+
#
# +-------+-------------------+
# |summary|        af_loudness|
# +-------+-------------------+
# |  count|           25869716|
# |   mean|-6.2314806194489964|
# | stddev| 2.5234440346500286|
# |    min|              -60.0|
# |    max|               11.0|
# +-------+-------------------+
#
# +-------+------------------+
# |summary|           af_mode|
# +-------+------------------+
# |  count|          25869892|
# |   mean|0.5671936770593944|
# | stddev|0.5616003222682756|
# |    min|           -37.264|
# |    max|              11.0|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|     af_speechiness|
# +-------+-------------------+
# |  count|           25869928|
# |   mean|0.10968943010719591|
# | stddev|0.11588382422835664|
# |    min|            -23.121|
# |    max|                8.0|
# +-------+-------------------+
#
# +-------+-------------------+
# |summary|    af_acousticness|
# +-------+-------------------+
# |  count|           25870005|
# |   mean| 0.2574340441193133|
# | stddev|0.24690402835620986|
# |    min|            -20.527|
# |    max|                7.0|
# +-------+-------------------+
#
# +-------+--------------------+
# |summary| af_instrumentalness|
# +-------+--------------------+
# |  count|            25870005|
# |   mean|0.013634176096179442|
# | stddev| 0.08713147386141538|
# |    min|              -5.092|
# |    max|                10.0|
# +-------+--------------------+
#
# +-------+-------------------+
# |summary|        af_liveness|
# +-------+-------------------+
# |  count|           25870007|
# |   mean|0.17262322573552094|
# | stddev| 16.692480726622524|
# |    min|             -5.676|
# |    max|            84884.0|
# +-------+-------------------+
#
# +-------+-------------------+
# |summary|         af_valence|
# +-------+-------------------+
# |  count|           25870005|
# |   mean| 0.5227647204905718|
# | stddev|0.22330044178900954|
# |    min|             -3.784|
# |    max|              0.999|
# +-------+-------------------+
#
# +-------+------------------+
# |summary|          af_tempo|
# +-------+------------------+
# |  count|          25870005|
# |   mean|121.07193108980927|
# | stddev| 29.54255743955878|
# |    min|               0.0|
# |    max|           238.431|
# +-------+------------------+
#
# +-------+------------------+
# |summary| af_time_signature|
# +-------+------------------+
# |  count|          25870007|
# |   mean| 4.043996244433176|
# | stddev|3.3711696667733126|
# |    min|               0.0|
# |    max|           230.094|
# +-------+------------------+

# %% [markdown]
# ## Missing Data

# %%
# Determine how many null values there are per attribute, and write findings to
# a new file.

nulls_dict = {}
with open('missing_info.txt', 'w') as file:
  for i, attribute in enumerate(df.columns):
    null_IDs = df[['ID']].where(df[attribute].isNull())
    nulls_dict[attribute] = (null_IDs, null_IDs.count())
    file.write(f'Attribute "{attribute}" contains {nulls_dict[attribute][1]} ' +
               f'nulls ({round((nulls_dict[attribute][1]/df_ct)*100, 2)}%).\n')
    print(f'Writing to "missing_info.txt"' +
          f'... {round(100 * (i + 1) / len(df.columns), 2)}% complete.')
print('Done!')
# Out:
# Writing to "missing_info.txt"... 3.45% complete.
# Writing to "missing_info.txt"... 6.9% complete.
# Writing to "missing_info.txt"... 10.34% complete.
# Writing to "missing_info.txt"... 13.79% complete.
# Writing to "missing_info.txt"... 17.24% complete.
# Writing to "missing_info.txt"... 20.69% complete.
# Writing to "missing_info.txt"... 24.14% complete.
# Writing to "missing_info.txt"... 27.59% complete.
# Writing to "missing_info.txt"... 31.03% complete.
# Writing to "missing_info.txt"... 34.48% complete.
# Writing to "missing_info.txt"... 37.93% complete.
# Writing to "missing_info.txt"... 41.38% complete.
# Writing to "missing_info.txt"... 44.83% complete.
# Writing to "missing_info.txt"... 48.28% complete.
# Writing to "missing_info.txt"... 51.72% complete.
# Writing to "missing_info.txt"... 55.17% complete.
# Writing to "missing_info.txt"... 58.62% complete.
# Writing to "missing_info.txt"... 62.07% complete.
# Writing to "missing_info.txt"... 65.52% complete.
# Writing to "missing_info.txt"... 68.97% complete.
# Writing to "missing_info.txt"... 72.41% complete.
# Writing to "missing_info.txt"... 75.86% complete.
# Writing to "missing_info.txt"... 79.31% complete.
# Writing to "missing_info.txt"... 82.76% complete.
# Writing to "missing_info.txt"... 86.21% complete.
# Writing to "missing_info.txt"... 89.66% complete.
# Writing to "missing_info.txt"... 93.1% complete.
# Writing to "missing_info.txt"... 96.55% complete.
# Writing to "missing_info.txt"... 100.0% complete.
# Done!

# %%
# We can easily view the outputs of the above file.

with open('missing_info.txt', 'r') as file:
  file_contents = file.read()
print(file_contents)
# Out:
# Attribute "ID" contains 0 nulls (0.0%).
# Attribute "title" contains 11 nulls (0.0%).
# Attribute "rank" contains 2142 nulls (0.01%).
# Attribute "date" contains 0 nulls (0.0%).
# Attribute "artist" contains 18 nulls (0.0%).
# Attribute "url" contains 0 nulls (0.0%).
# Attribute "region" contains 0 nulls (0.0%).
# Attribute "chart" contains 0 nulls (0.0%).
# Attribute "trend" contains 0 nulls (0.0%).
# Attribute "streams" contains 5856029 nulls (22.37%).
# Attribute "track_id" contains 306669 nulls (1.17%).
# Attribute "album" contains 323856 nulls (1.24%).
# Attribute "popularity" contains 320990 nulls (1.23%).
# Attribute "duration_ms" contains 306767 nulls (1.17%).
# Attribute "explicit" contains 304281 nulls (1.16%).
# Attribute "release_date" contains 304258 nulls (1.16%).
# Attribute "available_markets" contains 304249 nulls (1.16%).
# Attribute "af_danceability" contains 320803 nulls (1.23%).
# Attribute "af_energy" contains 306654 nulls (1.17%).
# Attribute "af_key" contains 304514 nulls (1.16%).
# Attribute "af_loudness" contains 304553 nulls (1.16%).
# Attribute "af_mode" contains 304377 nulls (1.16%).
# Attribute "af_speechiness" contains 304341 nulls (1.16%).
# Attribute "af_acousticness" contains 304264 nulls (1.16%).
# Attribute "af_instrumentalness" contains 304264 nulls (1.16%).
# Attribute "af_liveness" contains 304262 nulls (1.16%).
# Attribute "af_valence" contains 304264 nulls (1.16%).
# Attribute "af_tempo" contains 304264 nulls (1.16%).
# Attribute "af_time_signature" contains 304262 nulls (1.16%).

# %%
#Exploring categorical data

categorical_columns = ['region', 'chart', 'trend', 'explicit']
for column in categorical_columns:
    df.groupBy(column).count().orderBy('count', ascending=False).show()
# Out:
# +--------------+------+
# |        region| count|
# +--------------+------+
# |     Argentina|455186|
# | United States|454860|
# |        Brazil|454426|
# |       Austria|454384|
# |     Australia|453056|
# |        Canada|452096|
# |        Global|451688|
# |United Kingdom|450617|
# |   Switzerland|449491|
# |      Malaysia|449338|
# |       Denmark|449306|
# |         Italy|449299|
# |     Indonesia|449292|
# |       Belgium|449283|
# |        France|449268|
# |   Philippines|449249|
# |       Ecuador|449226|
# |      Colombia|449216|
# |       Ireland|449185|
# |   New Zealand|449184|
# +--------------+------+
# only showing top 20 rows
#
# +--------------------+--------+
# |               chart|   count|
# +--------------------+--------+
# |              top200|20318240|
# |             viral50| 5848699|
# |            Paraguay|     704|
# |             Germany|     555|
# |               Chile|     516|
# |https://open.spot...|     438|
# |https://open.spot...|     259|
# |               Spain|     231|
# |       United States|     214|
# |             Austria|     206|
# |              Canada|     187|
# |https://open.spot...|     176|
# |             Uruguay|     170|
# |         Switzerland|     159|
# |https://open.spot...|     147|
# |             Ireland|     145|
# |  Dominican Republic|     141|
# |           Argentina|     121|
# |                Peru|     120|
# |https://open.spot...|     118|
# +--------------------+--------+
# only showing top 20 rows
#
# +--------------------+--------+
# |               trend|   count|
# +--------------------+--------+
# |           MOVE_DOWN|11218010|
# |             MOVE_UP| 9798484|
# |       SAME_POSITION| 3297698|
# |           NEW_ENTRY| 1852747|
# |             viral50|    3116|
# |              top200|    2560|
# |  Dominican Republic|     601|
# |               India|     177|
# |              Panama|     110|
# |  Quimico Ultra Mega|      77|
# |            Honduras|      56|
# |           Nicaragua|      54|
# |          Costa Rica|      53|
# |             Bolivia|      36|
# |    Balbi El Chamaco|      35|
# |         Netherlands|      31|
# |               Spain|      28|
# |             Uruguay|      26|
# |https://open.spot...|      21|
# |              Israel|      19|
# +--------------------+--------+
# only showing top 20 rows
#
# +--------+--------+
# |explicit|   count|
# +--------+--------+
# |   False|18330116|
# |    True| 7523126|
# |    NULL|  304281|
# |326933.0|    9758|
# |192040.0|    1364|
# |     0.0|     841|
# |374545.0|     812|
# |208640.0|     545|
# |    58.0|     497|
# |223132.0|     370|
# |    55.0|     259|
# |152760.0|     218|
# |   Shaan|     176|
# |    38.0|     147|
# |    28.0|     132|
# |221480.0|     107|
# |186760.0|      93|
# |254608.0|      85|
# |194551.0|      58|
# |200453.0|      57|
# +--------+--------+
# only showing top 20 rows

# %%
#The outputs above can give us a hint on what we can remove from dataset

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Popularity vs Streams

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql.functions import col

# Select subset of data
data_subset = df.select("popularity", "streams").dropna().sample(fraction=0.2)

pandas_df = data_subset.toPandas()
# Out:
# Matplotlib created a temporary cache directory at /scratch/seltawil/job_30698017/matplotlib-dctl4pck because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(pandas_df['popularity'], pandas_df['streams'], alpha=0.5)
plt.title('Popularity vs Streams')
plt.xlabel('Popularity')
plt.ylabel('Streams')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Duration vs Popularity

# %%
data_subset = df.select(
    col("duration_ms"),
    col("popularity")
).na.drop()

sampled_data = data_subset.sample(fraction=0.1)
pandas_df = sampled_data.toPandas()

plt.figure(figsize=(10, 6))
plt.scatter(pandas_df['duration_ms'], pandas_df['popularity'], alpha=0.5, color='green')
plt.title('Track Duration vs Popularity')
plt.xlabel('Duration in milliseconds')
plt.ylabel('Popularity')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Stream vs Explicitness

# %%
explicit_streams = df.select(
    col("explicit"),
    col("streams")
).na.drop()

sampled_explicit_streams = explicit_streams.sample(fraction=0.1)

# Collect and plot
pandas_explicit_streams = sampled_explicit_streams.toPandas()

plt.figure(figsize=(10, 6))
plt.scatter(pandas_explicit_streams['explicit'], pandas_explicit_streams['streams'], alpha=0.5, color='red')
plt.title('Streams vs Explicitness')
plt.xlabel('Explicit')
plt.ylabel('Streams')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Popularity vs Region

# %%
region_popularity = df.groupBy("region").agg({'popularity': 'avg'}).na.drop()

sampled_region_popularity = region_popularity.sample(fraction=0.4)

pandas_region_popularity = sampled_region_popularity.toPandas()

plt.figure(figsize=(12, 8))
pandas_region_popularity.plot(kind='bar', x='region', y='avg(popularity)', color='purple')
plt.title('Average Popularity by Region')
plt.xlabel('Region')
plt.ylabel('Average Popularity')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Energy vs Loudness

# %%
energy_loudness = df.select(
    col("af_energy"),
    col("af_loudness")
).na.drop().sample(fraction=0.1)

pandas_energy_loudness = energy_loudness.toPandas()

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(pandas_energy_loudness['af_energy'], pandas_energy_loudness['af_loudness'], alpha=0.5)
plt.title('Energy vs Loudness of Tracks')
plt.xlabel('Energy')
plt.ylabel('Loudness (dB)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Tempo vs Danceability

# %%
tempo_danceability = df.select(
    col("af_tempo"),
    col("af_danceability")
).na.drop().sample(fraction=0.1)

pandas_tempo_danceability = tempo_danceability.toPandas()

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(pandas_tempo_danceability['af_tempo'], pandas_tempo_danceability['af_danceability'], alpha=0.5, color='blue')
plt.title('Tempo vs Danceability')
plt.xlabel('Tempo (Beats per Minute)')
plt.ylabel('Danceability')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Valence vs Acousticness

# %%
valence_acousticness = df.select(
    col("af_valence"),
    col("af_acousticness")
).na.drop().sample(fraction=0.1)

pandas_valence_acousticness = valence_acousticness.toPandas()

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(pandas_valence_acousticness['af_valence'], pandas_valence_acousticness['af_acousticness'], alpha=0.5, color='magenta')
plt.title('Valence vs Acousticness')
plt.xlabel('Valence')
plt.ylabel('Acousticness')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Popularity by Release Year

# %%
from pyspark.sql.functions import year

popularity_year = df.select(
    year(col("release_date")).alias("release_year"),
    col("popularity")
).na.drop().sample(fraction=0.3)

pandas_popularity_year = popularity_year.toPandas()

# Plotting
plt.figure(figsize=(12, 8))
plt.scatter(pandas_popularity_year['release_year'], pandas_popularity_year['popularity'], alpha=0.5, color='orange')
plt.title('Popularity by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Popularity')
plt.grid(True)
plt.show()

# %% [markdown]
# # Data cleaning

# %%
# See if there are any anomalies in missing data.

with open('missing_info.txt', 'r') as file:
  file_contents = file.read()
print(file_contents)
# Out:
# Attribute "ID" contains 0 nulls (0.0%).
# Attribute "title" contains 11 nulls (0.0%).
# Attribute "rank" contains 2142 nulls (0.01%).
# Attribute "date" contains 0 nulls (0.0%).
# Attribute "artist" contains 18 nulls (0.0%).
# Attribute "url" contains 0 nulls (0.0%).
# Attribute "region" contains 0 nulls (0.0%).
# Attribute "chart" contains 0 nulls (0.0%).
# Attribute "trend" contains 0 nulls (0.0%).
# Attribute "streams" contains 5856029 nulls (22.37%).
# Attribute "track_id" contains 306669 nulls (1.17%).
# Attribute "album" contains 323856 nulls (1.24%).
# Attribute "popularity" contains 320990 nulls (1.23%).
# Attribute "duration_ms" contains 306767 nulls (1.17%).
# Attribute "explicit" contains 304281 nulls (1.16%).
# Attribute "release_date" contains 304258 nulls (1.16%).
# Attribute "available_markets" contains 304249 nulls (1.16%).
# Attribute "af_danceability" contains 320803 nulls (1.23%).
# Attribute "af_energy" contains 306654 nulls (1.17%).
# Attribute "af_key" contains 304514 nulls (1.16%).
# Attribute "af_loudness" contains 304553 nulls (1.16%).
# Attribute "af_mode" contains 304377 nulls (1.16%).
# Attribute "af_speechiness" contains 304341 nulls (1.16%).
# Attribute "af_acousticness" contains 304264 nulls (1.16%).
# Attribute "af_instrumentalness" contains 304264 nulls (1.16%).
# Attribute "af_liveness" contains 304262 nulls (1.16%).
# Attribute "af_valence" contains 304264 nulls (1.16%).
# Attribute "af_tempo" contains 304264 nulls (1.16%).
# Attribute "af_time_signature" contains 304262 nulls (1.16%).

# %%
# As expected, many columns contain a significant proportion of nulls. (e.g.,
# "streams"). In preprocessing our data, handling such columns is especially
# important. Depending on the details of our analysis and the proportion of
# nulls contained in a given column, we may choose to drop or impute values on
# attributes containing nulls. E.g., if we sought to drop the "streams"
# attribute, we could simply implement the following:

df = df.drop('streams')
'streams' in df.columns
# Out:
# False

# %%
# Similarly, we may check if there are any rows which are entirely empty in our
# dataset.

emptyRowFinder = df
for attribute in df.columns[1:]:
  emptyRowFinder = emptyRowFinder.where(emptyRowFinder[attribute].isNull())
emptyRowFinder.show()

# As the below output shows, there are fortunately no entirely empty rows that
# need to be cleaned out of our dataset.
# Out:
# +---+-----+----+----+------+---+------+-----+-----+--------+-----+----------+-----------+--------+------------+-----------------+---------------+---------+------+-----------+-------+--------------+---------------+-------------------+-----------+----------+--------+-----------------+
# | ID|title|rank|date|artist|url|region|chart|trend|track_id|album|popularity|duration_ms|explicit|release_date|available_markets|af_danceability|af_energy|af_key|af_loudness|af_mode|af_speechiness|af_acousticness|af_instrumentalness|af_liveness|af_valence|af_tempo|af_time_signature|
# +---+-----+----+----+------+---+------+-----+-----+--------+-----+----------+-----------+--------+------------+-----------------+---------------+---------+------+-----------+-------+--------------+---------------+-------------------+-----------+----------+--------+-----------------+
# +---+-----+----+----+------+---+------+-----+-----+--------+-----+----------+-----------+--------+------------+-----------------+---------------+---------+------+-----------+-------+--------------+---------------+-------------------+-----------+----------+--------+-----------------+

# %%
df.head(10)
# Out:
# [Row(ID=0.0, title='Chantaje (feat. Maluma)', rank=1.0, date='2017-01-01', artist='Shakira', url='https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg', region='Argentina', chart='top200', trend='SAME_POSITION', track_id='6mICuAdrwEjh6Y6lroV2Kg', album='El Dorado', popularity=78.0, duration_ms=195840.0, explicit='False', release_date='2017-05-26', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability=0.8519999980926514, af_energy=0.7730000019073486, af_key=8.0, af_loudness=-2.9210000038146973, af_mode=0.0, af_speechiness=0.07760000228881836, af_acousticness=0.18700000643730164, af_instrumentalness=3.0499999411404133e-05, af_liveness=0.1589999943971634, af_valence=0.9070000052452087, af_tempo=102.03399658203125, af_time_signature=4.0),
#  Row(ID=1.0, title="Vente Pa' Ca (feat. Maluma)", rank=2.0, date='2017-01-01', artist='Ricky Martin', url='https://open.spotify.com/track/7DM4BPaS7uofFul3ywMe46', region='Argentina', chart='top200', trend='MOVE_UP', track_id='7DM4BPaS7uofFul3ywMe46', album="Vente Pa' Ca (feat. Maluma)", popularity=72.0, duration_ms=259195.0, explicit='False', release_date='2016-09-22', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability=0.6629999876022339, af_energy=0.9200000166893005, af_key=11.0, af_loudness=-4.070000171661377, af_mode=0.0, af_speechiness=0.22599999606609344, af_acousticness=0.004310000222176313, af_instrumentalness=1.6899999536690302e-05, af_liveness=0.10100000351667404, af_valence=0.5329999923706055, af_tempo=99.93499755859375, af_time_signature=4.0),
#  Row(ID=2.0, title='Reggaetón Lento (Bailemos)', rank=3.0, date='2017-01-01', artist='CNCO', url='https://open.spotify.com/track/3AEZUABDXNtecAOSC1qTfo', region='Argentina', chart='top200', trend='MOVE_DOWN', track_id='3AEZUABDXNtecAOSC1qTfo', album='Primera Cita', popularity=73.0, duration_ms=222560.0, explicit='False', release_date='2016-08-26', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability=0.7609999775886536, af_energy=0.8379999995231628, af_key=4.0, af_loudness=-3.072999954223633, af_mode=0.0, af_speechiness=0.050200000405311584, af_acousticness=0.4000000059604645, af_instrumentalness=0.0, af_liveness=0.17599999904632568, af_valence=0.7099999785423279, af_tempo=93.9739990234375, af_time_signature=4.0),
#  Row(ID=3.0, title='Safari', rank=4.0, date='2017-01-01', artist='J Balvin, Pharrell Williams, BIA, Sky', url='https://open.spotify.com/track/6rQSrBHf7HlZjtcMZ4S4bO', region='Argentina', chart='top200', trend='SAME_POSITION', track_id='6rQSrBHf7HlZjtcMZ4S4bO', album='Energía', popularity=0.0, duration_ms=205600.0, explicit='False', release_date='2016-06-24', available_markets='[]', af_danceability=0.5080000162124634, af_energy=0.6869999766349792, af_key=0.0, af_loudness=-4.361000061035156, af_mode=1.0, af_speechiness=0.32600000500679016, af_acousticness=0.5509999990463257, af_instrumentalness=3.4100000902981265e-06, af_liveness=0.12600000202655792, af_valence=0.5550000071525574, af_tempo=180.04400634765625, af_time_signature=4.0),
#  Row(ID=4.0, title='Shaky Shaky', rank=5.0, date='2017-01-01', artist='Daddy Yankee', url='https://open.spotify.com/track/58IL315gMSTD37DOZPJ2hf', region='Argentina', chart='top200', trend='MOVE_UP', track_id='58IL315gMSTD37DOZPJ2hf', album='Shaky Shaky', popularity=0.0, duration_ms=234320.0, explicit='False', release_date='2016-04-08', available_markets='[]', af_danceability=0.8989999890327454, af_energy=0.6259999871253967, af_key=6.0, af_loudness=-4.228000164031982, af_mode=0.0, af_speechiness=0.2919999957084656, af_acousticness=0.07599999755620956, af_instrumentalness=0.0, af_liveness=0.06310000270605087, af_valence=0.8730000257492065, af_tempo=88.00700378417969, af_time_signature=4.0),
#  Row(ID=5.0, title='Traicionera', rank=6.0, date='2017-01-01', artist='Sebastian Yatra', url='https://open.spotify.com/track/5J1c3M4EldCfNxXwrwt8mT', region='Argentina', chart='top200', trend='MOVE_DOWN', track_id='5J1c3M4EldCfNxXwrwt8mT', album='Traicionera', popularity=0.0, duration_ms=228466.0, explicit='False', release_date='2016-06-24', available_markets='[]', af_danceability=0.7760000228881836, af_energy=0.6690000295639038, af_key=11.0, af_loudness=-4.933000087738037, af_mode=1.0, af_speechiness=0.06379999965429306, af_acousticness=0.1420000046491623, af_instrumentalness=0.0, af_liveness=0.21899999678134918, af_valence=0.6610000133514404, af_tempo=91.01200103759766, af_time_signature=4.0),
#  Row(ID=6.0, title='Cuando Se Pone a Bailar', rank=7.0, date='2017-01-01', artist='Rombai', url='https://open.spotify.com/track/1MpKZi1zTXpERKwxmOu1PH', region='Argentina', chart='top200', trend='MOVE_DOWN', track_id='1MpKZi1zTXpERKwxmOu1PH', album='Cuando Se Pone a Bailar', popularity=56.0, duration_ms=195274.0, explicit='False', release_date='2016-12-02', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability=0.5879999995231628, af_energy=0.6819999814033508, af_key=11.0, af_loudness=-7.169000148773193, af_mode=0.0, af_speechiness=0.17299999296665192, af_acousticness=0.08510000258684158, af_instrumentalness=2.6899999284069054e-05, af_liveness=0.08399999886751175, af_valence=0.9369999766349792, af_tempo=205.64300537109375, af_time_signature=4.0),
#  Row(ID=7.0, title='Otra vez (feat. J Balvin)', rank=8.0, date='2017-01-01', artist='Zion & Lennox', url='https://open.spotify.com/track/3QwBODjSEzelZyVjxPOHdq', region='Argentina', chart='top200', trend='MOVE_DOWN', track_id='3QwBODjSEzelZyVjxPOHdq', album='Motivan2', popularity=74.0, duration_ms=209453.0, explicit='False', release_date='2016-09-30', available_markets="['AG', 'AM', 'AR', 'AT', 'AU', 'AZ', 'BB', 'BE', 'BF', 'BG', 'BN', 'BO', 'BR', 'BS', 'BW', 'BY', 'BZ', 'CA', 'CH', 'CL', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DK', 'DM', 'DO', 'EC', 'EE', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GB', 'GD', 'GH', 'GM', 'GR', 'GT', 'GW', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KE', 'KG', 'KH', 'KN', 'KR', 'KZ', 'LA', 'LI', 'LK', 'LT', 'LU', 'LV', 'MD', 'MN', 'MO', 'MT', 'MU', 'MV', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NZ', 'PA', 'PE', 'PG', 'PH', 'PL', 'PT', 'PY', 'RO', 'SE', 'SG', 'SI', 'SK', 'SV', 'SZ', 'TD', 'TH', 'TJ', 'TL', 'TR', 'TT', 'TW', 'UA', 'UG', 'US', 'UY', 'UZ', 'VE', 'VN', 'ZA', 'ZW']", af_danceability=0.8320000171661377, af_energy=0.7720000147819519, af_key=10.0, af_loudness=-5.428999900817871, af_mode=1.0, af_speechiness=0.10000000149011612, af_acousticness=0.05590000003576279, af_instrumentalness=0.00048600000445730984, af_liveness=0.4399999976158142, af_valence=0.7039999961853027, af_tempo=96.01599884033203, af_time_signature=4.0),
#  Row(ID=8.0, title='La Bicicleta', rank=9.0, date='2017-01-01', artist='Carlos Vives, Shakira', url='https://open.spotify.com/track/0sXvAOmXgjR2QUqLK1MltU', region='Argentina', chart='top200', trend='MOVE_UP', track_id='0sXvAOmXgjR2QUqLK1MltU', album='El Dorado', popularity=59.0, duration_ms=227706.0, explicit='False', release_date='2017-05-26', available_markets="['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']", af_danceability=0.7360000014305115, af_energy=0.9639999866485596, af_key=0.0, af_loudness=-2.1470000743865967, af_mode=1.0, af_speechiness=0.1289999932050705, af_acousticness=0.1979999989271164, af_instrumentalness=2.320000021427404e-06, af_liveness=0.335999995470047, af_valence=0.953000009059906, af_tempo=179.93499755859375, af_time_signature=4.0),
#  Row(ID=9.0, title='Dile Que Tu Me Quieres', rank=10.0, date='2017-01-01', artist='Ozuna', url='https://open.spotify.com/track/20ZAJdsKB5IGbGj4ilRt2o', region='Argentina', chart='top200', trend='MOVE_DOWN', track_id='20ZAJdsKB5IGbGj4ilRt2o', album='Dile Que Tu Me Quieres', popularity=0.0, duration_ms=226400.0, explicit='False', release_date='2016-06-06', available_markets='[]', af_danceability=0.7210000157356262, af_energy=0.6869999766349792, af_key=1.0, af_loudness=-6.682000160217285, af_mode=1.0, af_speechiness=0.07819999754428864, af_acousticness=0.0997999981045723, af_instrumentalness=0.0, af_liveness=0.06790000200271606, af_valence=0.824999988079071, af_tempo=175.91400146484375, af_time_signature=4.0)]

# %% [markdown]
# # Major Preprocessing
# This section includes scaling, imputing, encoding, and feature expansion.

# %% [markdown]
# Convert Columns to Float

# %%
from pyspark.sql.functions import col, regexp_replace

# Define the correct numeric attributes based on the schema
numeric_attributes = [
    'rank', 'popularity', 'duration_ms', 'af_danceability', 'af_energy', 'af_key',
    'af_loudness', 'af_mode', 'af_speechiness', 'af_acousticness', 'af_instrumentalness',
    'af_liveness', 'af_valence', 'af_tempo', 'af_time_signature'
]

# Remove non-numeric characters and cast columns to float
for column in numeric_attributes:
    df = df.withColumn(column, regexp_replace(col(column), '[^0-9.-]', '').cast('float'))

# Verify the schema to ensure correct types
df.printSchema()
# Out:
# root
#  |-- ID: float (nullable = true)
#  |-- title: string (nullable = true)
#  |-- rank: float (nullable = true)
#  |-- date: string (nullable = true)
#  |-- artist: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- chart: string (nullable = true)
#  |-- trend: string (nullable = true)
#  |-- track_id: string (nullable = true)
#  |-- album: string (nullable = true)
#  |-- popularity: float (nullable = true)
#  |-- duration_ms: float (nullable = true)
#  |-- explicit: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- available_markets: string (nullable = true)
#  |-- af_danceability: float (nullable = true)
#  |-- af_energy: float (nullable = true)
#  |-- af_key: float (nullable = true)
#  |-- af_loudness: float (nullable = true)
#  |-- af_mode: float (nullable = true)
#  |-- af_speechiness: float (nullable = true)
#  |-- af_acousticness: float (nullable = true)
#  |-- af_instrumentalness: float (nullable = true)
#  |-- af_liveness: float (nullable = true)
#  |-- af_valence: float (nullable = true)
#  |-- af_tempo: float (nullable = true)
#  |-- af_time_signature: float (nullable = true)

# %%
from pyspark.ml.feature import Imputer, StandardScaler, OneHotEncoder, StringIndexer, VectorAssembler, PolynomialExpansion
from pyspark.ml import Pipeline
from pyspark.ml.clustering import KMeans
import matplotlib.pyplot as plt

# Imputing missing data
imputer = Imputer(inputCols=numeric_attributes, outputCols=[f"{col}_imputed" for col in numeric_attributes])
df_imputed = imputer.fit(df).transform(df)

# Standardizing numeric features
assembler = VectorAssembler(inputCols=[f"{col}_imputed" for col in numeric_attributes], outputCol="numeric_features")
scaler = StandardScaler(inputCol="numeric_features", outputCol="scaled_features")
df_assembled = assembler.transform(df_imputed)
df_scaled = scaler.fit(df_assembled).transform(df_assembled)
# Out:
# Matplotlib created a temporary cache directory at /scratch/seltawil/job_30698631/matplotlib-aqbv805k because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
# Select categorical columns
categorical_cols = ['region', 'chart', 'trend', 'explicit']

# Encoding categorical features
indexers = [StringIndexer(inputCol=col, outputCol=f"{col}_indexed").setHandleInvalid('keep')
            for col in categorical_cols]
encoders = [OneHotEncoder(inputCol=f"{col}_indexed", outputCol=f"{col}_encoded") for col in categorical_cols]
pipeline = Pipeline(stages=indexers + encoders)
df_encoded = pipeline.fit(df_scaled).transform(df_scaled)

# %%
# Prepare features for clustering
features_for_clustering = ['scaled_features'] + [f"{col}_encoded" for col in categorical_cols]
assembler_clustering = VectorAssembler(inputCols=features_for_clustering, outputCol="features")
df_features = assembler_clustering.transform(df_encoded)

# %%
# Determine the optimal number of clusters using the elbow method
import gc
inertia = []
K = range(2, 11)
for k in K:
    try:
        gc.collect()
        kmeans = KMeans(k=k, seed=42, featuresCol='features')
        model = kmeans.fit(df_features)
        inertia.append(model.summary.trainingCost)
        print(f'{k - 1} models trained so far')
    except:
        print(f'Resources exhausted after successfully training {k - 2} models! Aborting model training.')
        break
# Out:
# 6 models trained so far
# 7 models trained so far
# 8 models trained so far
# 9 models trained so far

# %%
# Plot the elbow curve
plt.figure(figsize=(8, 6))
plt.plot(K, inertia, 'bo-')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# Fit KMeans with the optimal number of clusters
optimal_k = 7  # k = 7 ended up being optimal as the above elbow graph confirms
kmeans = KMeans(k=optimal_k, seed=42, featuresCol='features')
model = kmeans.fit(df_features)
clusters = model.transform(df_features)

# %%
# Get count of rows in each cluster.
cluster_counts = clusters.groupby('prediction').count().collect()
cluster_counts
# Out:
# [Row(prediction=1, count=14260),
#  Row(prediction=6, count=370584),
#  Row(prediction=3, count=176),
#  Row(prediction=5, count=11634716),
#  Row(prediction=4, count=5103910),
#  Row(prediction=0, count=9050622),
#  Row(prediction=2, count=1)]

# %%
# Sample from clusters.
sample_sizes = 40
samples = dict()
for row in cluster_counts:
    sample_ratio = float(min(1, sample_sizes / row['count']))
    samples[row['prediction']] = clusters.where(clusters['prediction'] ==
                                                row['prediction']).sample(fraction = sample_ratio)

# %%
# Verify that every sample has roughly 40 rows.
[samples[i].count() for i in range(optimal_k)]
# Out:
# [46, 51, 1, 45, 35, 47, 47]

# %%
# Note: Sample 2 ended up having only one observation! It is to be discarded from our analysis, but the fact that
# it was generated as a standalone cluster will need to be looked into.

# %%
# Save samples.

cpath = input('Please specify directory to which samples can be saved:')
samples_path = [cpath + '/sample' + str(i) for i in range(optimal_k)]
for i in range(optimal_k):
    samples[i].rdd.saveAsPickleFile(samples_path[i])
# Out:
# Please specify directory to which samples can be saved: /home/seltawil

# %%
# !tar cvf sample0.tar.gz sample0
# !tar cvf sample1.tar.gz sample1
# !tar cvf sample2.tar.gz sample2 # Bad sample!
# !tar cvf sample3.tar.gz sample3
# !tar cvf sample4.tar.gz sample4
# !tar cvf sample5.tar.gz sample5
# !tar cvf sample6.tar.gz sample6
# Out:
# /home/seltawil
# sample0/
# sample0/.part-00083.crc
# sample0/part-00036
# sample0/part-00041
# sample0/.part-00052.crc
# sample0/part-00146
# sample0/part-00131
# sample0/.part-00176.crc
# sample0/.part-00029.crc
# sample0/.part-00171.crc
# sample0/.part-00084.crc
# sample0/.part-00055.crc
# sample0/.part-00027.crc
# sample0/part-00109
# sample0/part-00073
# sample0/part-00190
# sample0/part-00004
# sample0/part-00103
# sample0/part-00097
# sample0/part-00174
# sample0/part-00079
# sample0/.part-00103.crc
# sample0/part-00200
# sample0/.part-00104.crc
# sample0/.part-00020.crc
# sample0/.part-00178.crc
# sample0/part-00058
# sample0/.part-00069.crc
# sample0/part-00155
# sample0/part-00122
# sample0/.part-00131.crc
# sample0/.part-00015.crc
# sample0/part-00025
# sample0/part-00052
# sample0/part-00128
# sample0/.part-00012.crc
# sample0/.part-00136.crc
# sample0/.part-00195.crc
# sample0/part-00189
# sample0/.part-00144.crc
# sample0/part-00110
# sample0/part-00084
# sample0/part-00167
# sample0/.part-00060.crc
# sample0/part-00060
# sample0/part-00183
# sample0/part-00017
# sample0/.part-00138.crc
# sample0/.part-00067.crc
# sample0/.part-00192.crc
# sample0/.part-00143.crc
# sample0/.part-00076.crc
# sample0/.part-00152.crc
# sample0/.part-00183.crc
# sample0/.part-00155.crc
# sample0/.part-00184.crc
# sample0/part-00160
# sample0/part-00083
# sample0/part-00117
# sample0/.part-00129.crc
# sample0/part-00089
# sample0/part-00010
# sample0/part-00184
# sample0/part-00067
# sample0/.part-00071.crc
# sample0/.part-00003.crc
# sample0/.part-00127.crc
# sample0/._SUCCESS.crc
# sample0/part-00125
# sample0/.part-00120.crc
# sample0/part-00152
# sample0/part-00028
# sample0/.part-00078.crc
# sample0/part-00158
# sample0/part-00055
# sample0/part-00022
# sample0/.part-00004.crc
# sample0/.part-00115.crc
# sample0/.part-00169.crc
# sample0/.part-00031.crc
# sample0/.part-00036.crc
# sample0/part-00003
# sample0/part-00197
# sample0/part-00074
# sample0/part-00179
# sample0/part-00009
# sample0/part-00173
# sample0/part-00090
# sample0/part-00104
# sample0/.part-00112.crc
# sample0/.part-00160.crc
# sample0/.part-00038.crc
# sample0/.part-00044.crc
# sample0/.part-00095.crc
# sample0/part-00046
# sample0/part-00031
# sample0/.part-00043.crc
# sample0/.part-00092.crc
# sample0/.part-00167.crc
# sample0/part-00136
# sample0/part-00141
# sample0/.part-00066.crc
# sample0/.part-00193.crc
# sample0/.part-00142.crc
# sample0/part-00132
# sample0/part-00145
# sample0/part-00048
# sample0/.part-00194.crc
# sample0/.part-00145.crc
# sample0/.part-00061.crc
# sample0/.part-00139.crc
# sample0/part-00138
# sample0/part-00042
# sample0/part-00035
# sample0/.part-00013.crc
# sample0/_SUCCESS
# sample0/.part-00137.crc
# sample0/.part-00068.crc
# sample0/part-00177
# sample0/part-00100
# sample0/part-00094
# sample0/part-00199
# sample0/.part-00130.crc
# sample0/.part-00014.crc
# sample0/part-00193
# sample0/part-00007
# sample0/part-00070
# sample0/.part-00105.crc
# sample0/.part-00021.crc
# sample0/.part-00179.crc
# sample0/part-00051
# sample0/part-00026
# sample0/.part-00026.crc
# sample0/.part-00102.crc
# sample0/part-00121
# sample0/part-00156
# sample0/.part-00028.crc
# sample0/.part-00170.crc
# sample0/.part-00085.crc
# sample0/.part-00054.crc
# sample0/.part-00082.crc
# sample0/.part-00053.crc
# sample0/part-00180
# sample0/part-00014
# sample0/part-00063
# sample0/part-00119
# sample0/part-00069
# sample0/part-00164
# sample0/part-00113
# sample0/part-00087
# sample0/.part-00177.crc
# sample0/part-00169
# sample0/part-00064
# sample0/.part-00042.crc
# sample0/part-00013
# sample0/part-00187
# sample0/.part-00093.crc
# sample0/part-00080
# sample0/part-00114
# sample0/part-00163
# sample0/part-00019
# sample0/.part-00166.crc
# sample0/.part-00161.crc
# sample0/.part-00039.crc
# sample0/.part-00045.crc
# sample0/.part-00094.crc
# sample0/part-00021
# sample0/part-00056
# sample0/.part-00037.crc
# sample0/.part-00113.crc
# sample0/part-00151
# sample0/part-00126
# sample0/.part-00114.crc
# sample0/.part-00168.crc
# sample0/.part-00030.crc
# sample0/.part-00121.crc
# sample0/part-00093
# sample0/part-00107
# sample0/part-00170
# sample0/.part-00079.crc
# sample0/part-00077
# sample0/part-00000
# sample0/part-00194
# sample0/part-00099
# sample0/.part-00005.crc
# sample0/.part-00002.crc
# sample0/.part-00126.crc
# sample0/.part-00154.crc
# sample0/part-00038
# sample0/part-00142
# sample0/part-00135
# sample0/.part-00185.crc
# sample0/.part-00128.crc
# sample0/.part-00070.crc
# sample0/part-00032
# sample0/part-00045
# sample0/part-00148
# sample0/.part-00077.crc
# sample0/.part-00153.crc
# sample0/.part-00182.crc
# sample0/.part-00162.crc
# sample0/.part-00046.crc
# sample0/.part-00097.crc
# sample0/.part-00119.crc
# sample0/.part-00041.crc
# sample0/part-00008
# sample0/part-00091
# sample0/part-00105
# sample0/.part-00090.crc
# sample0/part-00172
# sample0/part-00075
# sample0/.part-00165.crc
# sample0/part-00002
# sample0/part-00196
# sample0/part-00178
# sample0/.part-00200.crc
# sample0/.part-00117.crc
# sample0/.part-00033.crc
# sample0/part-00140
# sample0/part-00137
# sample0/.part-00034.crc
# sample0/.part-00110.crc
# sample0/.part-00048.crc
# sample0/part-00030
# sample0/part-00047
# sample0/.part-00099.crc
# sample0/.part-00159.crc
# sample0/.part-00188.crc
# sample0/.part-00001.crc
# sample0/.part-00125.crc
# sample0/.part-00122.crc
# sample0/part-00088
# sample0/part-00066
# sample0/part-00011
# sample0/part-00185
# sample0/part-00082
# sample0/part-00116
# sample0/part-00161
# sample0/.part-00006.crc
# sample0/.part-00074.crc
# sample0/.part-00150.crc
# sample0/.part-00181.crc
# sample0/.part-00008.crc
# sample0/part-00159
# sample0/part-00023
# sample0/part-00054
# sample0/.part-00157.crc
# sample0/.part-00186.crc
# sample0/part-00153
# sample0/part-00124
# sample0/part-00029
# sample0/.part-00073.crc
# sample0/part-00053
# sample0/part-00024
# sample0/part-00129
# sample0/.part-00197.crc
# sample0/.part-00146.crc
# sample0/.part-00062.crc
# sample0/part-00059
# sample0/part-00123
# sample0/part-00154
# sample0/.part-00065.crc
# sample0/.part-00019.crc
# sample0/.part-00190.crc
# sample0/.part-00141.crc
# sample0/part-00182
# sample0/part-00016
# sample0/part-00061
# sample0/.part-00133.crc
# sample0/.part-00017.crc
# sample0/part-00188
# sample0/part-00166
# sample0/part-00111
# sample0/part-00085
# sample0/.part-00010.crc
# sample0/.part-00199.crc
# sample0/.part-00148.crc
# sample0/.part-00134.crc
# sample0/part-00130
# sample0/part-00147
# sample0/.part-00025.crc
# sample0/.part-00088.crc
# sample0/.part-00059.crc
# sample0/.part-00101.crc
# sample0/part-00040
# sample0/part-00037
# sample0/.part-00106.crc
# sample0/.part-00022.crc
# sample0/.part-00081.crc
# sample0/.part-00050.crc
# sample0/.part-00108.crc
# sample0/part-00175
# sample0/part-00102
# sample0/part-00096
# sample0/part-00078
# sample0/part-00108
# sample0/part-00191
# sample0/part-00005
# sample0/part-00072
# sample0/.part-00174.crc
# sample0/.part-00173.crc
# sample0/.part-00086.crc
# sample0/.part-00057.crc
# sample0/part-00201
# sample0/.part-00156.crc
# sample0/.part-00187.crc
# sample0/part-00001
# sample0/part-00195
# sample0/part-00076
# sample0/part-00098
# sample0/part-00171
# sample0/part-00092
# sample0/part-00106
# sample0/.part-00072.crc
# sample0/.part-00075.crc
# sample0/.part-00151.crc
# sample0/.part-00180.crc
# sample0/.part-00009.crc
# sample0/.part-00123.crc
# sample0/part-00044
# sample0/part-00033
# sample0/part-00149
# sample0/part-00039
# sample0/part-00134
# sample0/.part-00007.crc
# sample0/part-00143
# sample0/.part-00158.crc
# sample0/.part-00189.crc
# sample0/.part-00000.crc
# sample0/.part-00124.crc
# sample0/part-00162
# sample0/.part-00035.crc
# sample0/part-00081
# sample0/part-00115
# sample0/part-00018
# sample0/part-00168
# sample0/part-00012
# sample0/part-00186
# sample0/part-00065
# sample0/.part-00111.crc
# sample0/.part-00049.crc
# sample0/.part-00098.crc
# sample0/.part-00201.crc
# sample0/.part-00116.crc
# sample0/.part-00032.crc
# sample0/part-00127
# sample0/.part-00118.crc
# sample0/part-00150
# sample0/.part-00040.crc
# sample0/.part-00091.crc
# sample0/.part-00164.crc
# sample0/part-00057
# sample0/part-00020
# sample0/.part-00163.crc
# sample0/.part-00047.crc
# sample0/.part-00096.crc
# sample0/.part-00172.crc
# sample0/.part-00087.crc
# sample0/.part-00056.crc
# sample0/.part-00080.crc
# sample0/.part-00051.crc
# sample0/part-00157
# sample0/part-00120
# sample0/.part-00109.crc
# sample0/.part-00175.crc
# sample0/part-00027
# sample0/part-00050
# sample0/.part-00107.crc
# sample0/.part-00023.crc
# sample0/.part-00024.crc
# sample0/part-00068
# sample0/part-00112
# sample0/part-00086
# sample0/part-00165
# sample0/part-00062
# sample0/part-00181
# sample0/part-00015
# sample0/part-00118
# sample0/.part-00089.crc
# sample0/.part-00058.crc
# sample0/.part-00100.crc
# sample0/.part-00011.crc
# sample0/.part-00198.crc
# sample0/.part-00149.crc
# sample0/.part-00135.crc
# sample0/part-00139
# sample0/part-00034
# sample0/part-00043
# sample0/.part-00132.crc
# sample0/.part-00016.crc
# sample0/part-00144
# sample0/part-00133
# sample0/part-00049
# sample0/.part-00064.crc
# sample0/.part-00018.crc
# sample0/.part-00191.crc
# sample0/.part-00140.crc
# sample0/.part-00196.crc
# sample0/part-00071
# sample0/part-00192
# sample0/part-00006
# sample0/.part-00147.crc
# sample0/part-00101
# sample0/part-00095
# sample0/part-00176
# sample0/part-00198
# sample0/.part-00063.crc
# sample1/
# sample1/.part-00124.crc
# sample1/.part-00189.crc
# sample1/.part-00158.crc
# sample1/.part-00000.crc
# sample1/.part-00007.crc
# sample1/part-00161
# sample1/part-00082
# sample1/part-00116
# sample1/part-00011
# sample1/part-00185
# sample1/.part-00123.crc
# sample1/part-00066
# sample1/part-00088
# sample1/.part-00180.crc
# sample1/.part-00151.crc
# sample1/.part-00009.crc
# sample1/.part-00075.crc
# sample1/part-00029
# sample1/part-00124
# sample1/part-00153
# sample1/.part-00072.crc
# sample1/.part-00187.crc
# sample1/.part-00156.crc
# sample1/part-00054
# sample1/part-00023
# sample1/part-00159
# sample1/.part-00096.crc
# sample1/.part-00047.crc
# sample1/.part-00163.crc
# sample1/.part-00164.crc
# sample1/part-00178
# sample1/part-00002
# sample1/part-00196
# sample1/part-00075
# sample1/.part-00118.crc
# sample1/part-00172
# sample1/part-00091
# sample1/part-00105
# sample1/part-00008
# sample1/.part-00091.crc
# sample1/.part-00040.crc
# sample1/.part-00032.crc
# sample1/.part-00116.crc
# sample1/.part-00201.crc
# sample1/part-00047
# sample1/part-00030
# sample1/.part-00111.crc
# sample1/.part-00098.crc
# sample1/.part-00049.crc
# sample1/part-00137
# sample1/part-00140
# sample1/.part-00035.crc
# sample1/part-00037
# sample1/part-00040
# sample1/.part-00058.crc
# sample1/.part-00089.crc
# sample1/.part-00100.crc
# sample1/.part-00024.crc
# sample1/part-00147
# sample1/part-00130
# sample1/.part-00023.crc
# sample1/.part-00107.crc
# sample1/part-00072
# sample1/part-00191
# sample1/part-00005
# sample1/.part-00175.crc
# sample1/part-00108
# sample1/.part-00051.crc
# sample1/.part-00080.crc
# sample1/part-00078
# sample1/part-00102
# sample1/part-00096
# sample1/part-00175
# sample1/.part-00109.crc
# sample1/.part-00056.crc
# sample1/part-00201
# sample1/.part-00087.crc
# sample1/.part-00172.crc
# sample1/part-00154
# sample1/part-00123
# sample1/part-00059
# sample1/.part-00063.crc
# sample1/.part-00147.crc
# sample1/part-00129
# sample1/part-00024
# sample1/part-00053
# sample1/.part-00196.crc
# sample1/.part-00018.crc
# sample1/.part-00140.crc
# sample1/.part-00191.crc
# sample1/.part-00064.crc
# sample1/.part-00016.crc
# sample1/part-00111
# sample1/part-00085
# sample1/part-00166
# sample1/part-00188
# sample1/part-00061
# sample1/part-00182
# sample1/part-00016
# sample1/.part-00132.crc
# sample1/.part-00135.crc
# sample1/.part-00011.crc
# sample1/.part-00149.crc
# sample1/.part-00198.crc
# sample1/.part-00110.crc
# sample1/.part-00099.crc
# sample1/part-00065
# sample1/part-00012
# sample1/part-00186
# sample1/part-00168
# sample1/.part-00048.crc
# sample1/part-00018
# sample1/part-00081
# sample1/part-00115
# sample1/part-00162
# sample1/.part-00034.crc
# sample1/.part-00033.crc
# sample1/.part-00117.crc
# sample1/.part-00200.crc
# sample1/.part-00165.crc
# sample1/part-00020
# sample1/part-00057
# sample1/.part-00119.crc
# sample1/.part-00090.crc
# sample1/part-00150
# sample1/.part-00041.crc
# sample1/part-00127
# sample1/.part-00097.crc
# sample1/.part-00046.crc
# sample1/.part-00162.crc
# sample1/part-00092
# sample1/.part-00073.crc
# sample1/part-00106
# sample1/part-00171
# sample1/part-00098
# sample1/part-00076
# sample1/part-00001
# sample1/part-00195
# sample1/.part-00186.crc
# sample1/.part-00157.crc
# sample1/.part-00181.crc
# sample1/.part-00150.crc
# sample1/.part-00008.crc
# sample1/.part-00074.crc
# sample1/part-00143
# sample1/part-00134
# sample1/part-00039
# sample1/.part-00006.crc
# sample1/.part-00122.crc
# sample1/part-00149
# sample1/part-00033
# sample1/part-00044
# sample1/.part-00125.crc
# sample1/.part-00188.crc
# sample1/.part-00159.crc
# sample1/.part-00001.crc
# sample1/.part-00134.crc
# sample1/.part-00010.crc
# sample1/.part-00148.crc
# sample1/.part-00199.crc
# sample1/.part-00017.crc
# sample1/part-00049
# sample1/part-00133
# sample1/part-00144
# sample1/.part-00133.crc
# sample1/part-00043
# sample1/part-00034
# sample1/part-00139
# sample1/.part-00019.crc
# sample1/.part-00141.crc
# sample1/.part-00190.crc
# sample1/.part-00065.crc
# sample1/.part-00062.crc
# sample1/part-00198
# sample1/part-00176
# sample1/part-00101
# sample1/part-00095
# sample1/part-00192
# sample1/part-00006
# sample1/part-00071
# sample1/.part-00146.crc
# sample1/.part-00197.crc
# sample1/.part-00057.crc
# sample1/.part-00086.crc
# sample1/.part-00173.crc
# sample1/part-00050
# sample1/part-00027
# sample1/.part-00174.crc
# sample1/.part-00050.crc
# sample1/.part-00081.crc
# sample1/part-00120
# sample1/part-00157
# sample1/.part-00108.crc
# sample1/.part-00022.crc
# sample1/.part-00106.crc
# sample1/.part-00059.crc
# sample1/.part-00088.crc
# sample1/part-00118
# sample1/part-00181
# sample1/part-00015
# sample1/part-00062
# sample1/.part-00101.crc
# sample1/part-00165
# sample1/part-00112
# sample1/part-00086
# sample1/part-00068
# sample1/.part-00025.crc
# sample1/part-00128
# sample1/part-00052
# sample1/part-00025
# sample1/.part-00014.crc
# sample1/.part-00068.crc
# sample1/part-00122
# sample1/part-00155
# sample1/.part-00130.crc
# sample1/part-00058
# sample1/.part-00137.crc
# sample1/.part-00013.crc
# sample1/.part-00061.crc
# sample1/.part-00139.crc
# sample1/part-00183
# sample1/part-00017
# sample1/part-00060
# sample1/part-00167
# sample1/part-00110
# sample1/part-00084
# sample1/part-00189
# sample1/.part-00145.crc
# sample1/.part-00194.crc
# sample1/.part-00142.crc
# sample1/.part-00193.crc
# sample1/.part-00066.crc
# sample1/part-00131
# sample1/part-00146
# sample1/.part-00177.crc
# sample1/.part-00053.crc
# sample1/.part-00082.crc
# sample1/part-00041
# sample1/part-00036
# sample1/.part-00054.crc
# sample1/.part-00085.crc
# sample1/.part-00028.crc
# sample1/.part-00170.crc
# sample1/part-00079
# sample1/.part-00102.crc
# sample1/part-00174
# sample1/part-00103
# sample1/part-00097
# sample1/.part-00026.crc
# sample1/part-00190
# sample1/part-00004
# sample1/part-00073
# sample1/part-00109
# sample1/.part-00021.crc
# sample1/.part-00179.crc
# sample1/part-00200
# sample1/.part-00105.crc
# sample1/.part-00168.crc
# sample1/.part-00030.crc
# sample1/.part-00114.crc
# sample1/.part-00113.crc
# sample1/part-00090
# sample1/part-00104
# sample1/part-00173
# sample1/part-00009
# sample1/part-00179
# sample1/part-00074
# sample1/part-00003
# sample1/part-00197
# sample1/.part-00037.crc
# sample1/.part-00094.crc
# sample1/.part-00045.crc
# sample1/.part-00161.crc
# sample1/.part-00039.crc
# sample1/part-00141
# sample1/.part-00166.crc
# sample1/part-00136
# sample1/.part-00093.crc
# sample1/part-00031
# sample1/part-00046
# sample1/.part-00042.crc
# sample1/.part-00182.crc
# sample1/.part-00153.crc
# sample1/.part-00077.crc
# sample1/.part-00128.crc
# sample1/.part-00070.crc
# sample1/part-00067
# sample1/part-00010
# sample1/part-00184
# sample1/part-00089
# sample1/.part-00185.crc
# sample1/part-00083
# sample1/part-00117
# sample1/part-00160
# sample1/.part-00154.crc
# sample1/.part-00126.crc
# sample1/.part-00002.crc
# sample1/part-00022
# sample1/part-00055
# sample1/part-00158
# sample1/.part-00005.crc
# sample1/.part-00121.crc
# sample1/part-00028
# sample1/part-00152
# sample1/.part-00079.crc
# sample1/part-00125
# sample1/.part-00020.crc
# sample1/.part-00178.crc
# sample1/.part-00104.crc
# sample1/part-00156
# sample1/part-00121
# sample1/.part-00103.crc
# sample1/.part-00027.crc
# sample1/part-00026
# sample1/part-00051
# sample1/.part-00055.crc
# sample1/.part-00084.crc
# sample1/.part-00029.crc
# sample1/.part-00171.crc
# sample1/part-00113
# sample1/part-00087
# sample1/part-00164
# sample1/part-00069
# sample1/.part-00176.crc
# sample1/part-00119
# sample1/.part-00052.crc
# sample1/part-00063
# sample1/part-00180
# sample1/part-00014
# sample1/.part-00083.crc
# sample1/.part-00143.crc
# sample1/.part-00192.crc
# sample1/.part-00067.crc
# sample1/part-00035
# sample1/part-00042
# sample1/part-00138
# sample1/.part-00060.crc
# sample1/.part-00138.crc
# sample1/.part-00144.crc
# sample1/.part-00195.crc
# sample1/part-00048
# sample1/part-00145
# sample1/part-00132
# sample1/.part-00136.crc
# sample1/.part-00012.crc
# sample1/.part-00015.crc
# sample1/part-00070
# sample1/part-00193
# sample1/part-00007
# sample1/part-00199
# sample1/part-00100
# sample1/part-00094
# sample1/part-00177
# sample1/.part-00069.crc
# sample1/.part-00131.crc
# sample1/part-00099
# sample1/part-00000
# sample1/.part-00004.crc
# sample1/part-00194
# sample1/part-00077
# sample1/part-00170
# sample1/part-00093
# sample1/part-00107
# sample1/.part-00120.crc
# sample1/.part-00078.crc
# sample1/.part-00127.crc
# sample1/._SUCCESS.crc
# sample1/.part-00003.crc
# sample1/part-00148
# sample1/part-00045
# sample1/.part-00129.crc
# sample1/part-00032
# sample1/.part-00071.crc
# sample1/.part-00184.crc
# sample1/.part-00155.crc
# sample1/part-00135
# sample1/part-00142
# sample1/part-00038
# sample1/.part-00183.crc
# sample1/.part-00152.crc
# sample1/.part-00076.crc
# sample1/.part-00167.crc
# sample1/part-00019
# sample1/part-00163
# sample1/part-00080
# sample1/part-00114
# sample1/part-00013
# sample1/part-00187
# sample1/part-00064
# sample1/part-00169
# sample1/.part-00092.crc
# sample1/.part-00043.crc
# sample1/.part-00095.crc
# sample1/.part-00044.crc
# sample1/.part-00160.crc
# sample1/.part-00038.crc
# sample1/.part-00112.crc
# sample1/part-00126
# sample1/part-00151
# sample1/_SUCCESS
# sample1/.part-00036.crc
# sample1/part-00056
# sample1/part-00021
# sample1/.part-00169.crc
# sample1/.part-00031.crc
# sample1/.part-00115.crc
# sample2/
# sample2/.part-00127.crc
# sample2/part-00086
# sample2/part-00112
# sample2/part-00165
# sample2/part-00068
# sample2/part-00118
# sample2/part-00062
# sample2/part-00015
# sample2/part-00181
# sample2/.part-00003.crc
# sample2/.part-00004.crc
# sample2/.part-00120.crc
# sample2/.part-00078.crc
# sample2/.part-00183.crc
# sample2/part-00157
# sample2/part-00120
# sample2/.part-00152.crc
# sample2/.part-00076.crc
# sample2/part-00027
# sample2/part-00050
# sample2/.part-00129.crc
# sample2/.part-00071.crc
# sample2/.part-00184.crc
# sample2/.part-00155.crc
# sample2/part-00071
# sample2/part-00006
# sample2/part-00192
# sample2/.part-00095.crc
# sample2/.part-00044.crc
# sample2/.part-00160.crc
# sample2/part-00198
# sample2/part-00095
# sample4/.part-00129.crc
# sample4/part-00147
# sample4/part-00130
# sample4/.part-00076.crc
# sample4/.part-00183.crc
# sample4/part-00037
# sample4/part-00040
# sample4/.part-00152.crc
# sample4/.part-00092.crc
# sample4/.part-00043.crc
# sample4/.part-00167.crc
# sample4/.part-00038.crc
# sample4/.part-00160.crc
# sample4/part-00061
# sample4/part-00016
# sample4/part-00182
# sample4/.part-00095.crc
# sample4/part-00085
# sample4/part-00111
# sample4/part-00166
# sample4/.part-00044.crc
# sample4/part-00188
# sample4/.part-00036.crc
# sample4/.part-00112.crc
# sample4/part-00129
# sample4/part-00024
# sample4/part-00053
# sample4/.part-00115.crc
# sample4/.part-00031.crc
# sample4/.part-00169.crc
# sample4/part-00154
# sample4/part-00123
# sample4/part-00059
# sample5/
# sample5/.part-00118.crc
# sample5/part-00131
# sample5/part-00146
# sample5/.part-00091.crc
# sample5/.part-00040.crc
# sample5/.part-00164.crc
# sample5/part-00041
# sample5/part-00036
# sample5/.part-00163.crc
# sample5/.part-00096.crc
# sample5/.part-00047.crc
# sample5/part-00079
# sample5/part-00174
# sample5/.part-00035.crc
# sample5/part-00103
# sample5/part-00097
# sample5/.part-00111.crc
# sample5/part-00190
# sample5/part-00004
# sample5/part-00073
# sample5/part-00109
# sample5/.part-00098.crc
# sample5/.part-00049.crc
# sample5/.part-00116.crc
# sample5/.part-00201.crc
# sample5/part-00200
# sample5/.part-00032.crc
# sample5/part-00128
# sample5/part-00052
# sample5/part-00025
# sample5/.part-00123.crc
# sample5/part-00122
# sample5/part-00155
# sample5/.part-00007.crc
# sample5/part-00058
# sample5/.part-00189.crc
# sample5/.part-00158.crc
# sample5/.part-00000.crc
# sample5/.part-00124.crc
# sample5/.part-00187.crc
# sample5/.part-00156.crc
# sample5/part-00183
# sample5/part-00017
# sample5/part-00060
# sample5/part-00167
# sample5/part-00110
# sample5/part-00084
# sample5/part-00189
# sample5/.part-00072.crc
# sample5/.part-00075.crc
# sample5/.part-00180.crc
# sample5/.part-00151.crc
# sample5/.part-00009.crc
# sample5/.part-00064.crc
# sample5/.part-00018.crc
# sample5/.part-00140.crc
# sample5/.part-00191.crc
# sample5/.part-00147.crc
# sample5/part-00067
# sample5/part-00010
# sample5/part-00184
# sample5/.part-00196.crc
# sample5/part-00089
# sample5/.part-00063.crc
# sample5/part-00083
# sample5/part-00117
# sample5/part-00160
# sample5/.part-00011.crc
# sample5/.part-00149.crc
# sample5/.part-00198.crc
# sample5/.part-00135.crc
# sample5/part-00022
# sample5/._SUCCESS.crc
# sample5/part-00055
# sample5/part-00158
# sample5/.part-00132.crc
# sample5/.part-00016.crc
# sample5/part-00028
# sample5/part-00152
# sample5/part-00125
# sample5/.part-00107.crc
# sample5/.part-00023.crc
# sample5/.part-00024.crc
# sample5/part-00090
# sample5/part-00104
# sample5/part-00173
# sample5/part-00009
# sample5/.part-00058.crc
# sample5/part-00179
# sample5/.part-00089.crc
# sample5/part-00074
# sample5/part-00003
# sample5/part-00197
# sample5/.part-00100.crc
# sample5/.part-00172.crc
# sample5/.part-00056.crc
# sample5/.part-00087.crc
# sample5/part-00141
# sample5/part-00136
# sample5/.part-00051.crc
# sample5/.part-00080.crc
# sample5/.part-00109.crc
# sample5/part-00031
# sample5/part-00046
# sample5/.part-00175.crc
# sample5/.part-00074.crc
# sample5/.part-00181.crc
# sample5/.part-00150.crc
# sample5/.part-00008.crc
# sample5/.part-00186.crc
# sample5/part-00035
# sample5/.part-00157.crc
# sample5/part-00042
# sample5/part-00138
# sample5/.part-00073.crc
# sample5/part-00048
# sample5/part-00145
# sample5/part-00132
# sample5/.part-00188.crc
# sample5/.part-00159.crc
# sample5/.part-00001.crc
# sample5/.part-00125.crc
# sample5/.part-00122.crc
# sample5/part-00070
# sample5/part-00193
# sample5/part-00007
# sample5/part-00199
# sample5/part-00100
# sample5/part-00094
# sample5/part-00177
# sample5/.part-00006.crc
# sample5/.part-00117.crc
# sample5/.part-00200.crc
# sample5/.part-00033.crc
# sample5/part-00156
# sample5/part-00121
# sample5/.part-00034.crc
# sample5/.part-00110.crc
# sample5/.part-00099.crc
# sample5/part-00026
# sample5/.part-00048.crc
# sample5/part-00051
# sample5/.part-00162.crc
# sample5/.part-00097.crc
# sample5/.part-00046.crc
# sample5/.part-00119.crc
# sample5/part-00113
# sample5/part-00087
# sample5/part-00164
# sample5/.part-00090.crc
# sample5/part-00069
# sample5/.part-00041.crc
# sample5/part-00119
# sample5/.part-00165.crc
# sample5/part-00063
# sample5/part-00180
# sample5/part-00014
# sample5/.part-00050.crc
# sample5/.part-00081.crc
# sample5/part-00019
# sample5/part-00163
# sample5/part-00080
# sample5/part-00114
# sample5/.part-00108.crc
# sample5/part-00013
# sample5/part-00187
# sample5/part-00064
# sample5/part-00169
# sample5/.part-00174.crc
# sample5/.part-00173.crc
# sample5/.part-00057.crc
# sample5/.part-00086.crc
# sample5/.part-00025.crc
# sample5/part-00126
# sample5/part-00151
# sample5/.part-00059.crc
# sample5/.part-00088.crc
# sample5/part-00056
# sample5/part-00021
# sample5/.part-00101.crc
# sample5/.part-00106.crc
# sample5/.part-00022.crc
# sample5/_SUCCESS
# sample5/part-00099
# sample5/.part-00133.crc
# sample5/part-00000
# sample5/part-00194
# sample5/part-00077
# sample5/part-00170
# sample5/part-00093
# sample5/part-00107
# sample5/.part-00017.crc
# sample5/.part-00010.crc
# sample5/.part-00148.crc
# sample5/.part-00199.crc
# sample5/.part-00134.crc
# sample5/part-00148
# sample5/part-00045
# sample5/part-00032
# sample5/.part-00146.crc
# sample5/.part-00197.crc
# sample5/.part-00062.crc
# sample5/part-00135
# sample5/part-00142
# sample5/part-00038
# sample5/.part-00065.crc
# sample5/.part-00019.crc
# sample5/.part-00141.crc
# sample5/.part-00190.crc
# sample5/.part-00028.crc
# sample5/.part-00170.crc
# sample5/.part-00054.crc
# sample5/.part-00085.crc
# sample5/.part-00053.crc
# sample5/.part-00082.crc
# sample5/part-00178
# sample5/part-00002
# sample5/part-00196
# sample5/part-00075
# sample5/part-00172
# sample5/part-00091
# sample5/part-00105
# sample5/part-00008
# sample5/.part-00177.crc
# sample5/.part-00105.crc
# sample5/.part-00021.crc
# sample5/.part-00179.crc
# sample5/.part-00026.crc
# sample5/part-00047
# sample5/part-00030
# sample5/part-00137
# sample5/part-00140
# sample5/.part-00102.crc
# sample5/.part-00013.crc
# sample5/.part-00137.crc
# sample5/.part-00068.crc
# sample5/.part-00130.crc
# sample5/part-00161
# sample5/part-00082
# sample5/part-00116
# sample5/part-00011
# sample5/part-00185
# sample5/part-00066
# sample5/part-00088
# sample5/.part-00014.crc
# sample5/.part-00066.crc
# sample5/.part-00142.crc
# sample5/.part-00193.crc
# sample5/part-00029
# sample5/part-00124
# sample5/part-00153
# sample5/.part-00145.crc
# sample5/.part-00194.crc
# sample5/.part-00061.crc
# sample5/part-00054
# sample5/part-00023
# sample5/part-00159
# sample5/.part-00139.crc
# sample5/part-00154
# sample5/.part-00185.crc
# sample5/part-00123
# sample5/part-00059
# sample5/.part-00154.crc
# sample5/.part-00128.crc
# sample5/part-00129
# sample5/part-00024
# sample5/.part-00070.crc
# sample5/part-00053
# sample5/.part-00077.crc
# sample5/.part-00182.crc
# sample5/.part-00153.crc
# sample5/.part-00121.crc
# sample5/.part-00079.crc
# sample5/part-00111
# sample5/part-00085
# sample5/part-00166
# sample5/part-00188
# sample5/part-00061
# sample5/part-00182
# sample5/part-00016
# sample5/.part-00005.crc
# sample5/.part-00002.crc
# sample5/.part-00126.crc
# sample5/part-00037
# sample5/part-00040
# sample5/.part-00037.crc
# sample5/.part-00113.crc
# sample5/part-00147
# sample5/part-00130
# sample5/.part-00114.crc
# sample5/.part-00168.crc
# sample5/.part-00030.crc
# sample5/.part-00093.crc
# sample5/part-00072
# sample5/part-00191
# sample5/.part-00042.crc
# sample5/part-00005
# sample5/part-00108
# sample5/.part-00166.crc
# sample5/part-00078
# sample5/part-00102
# sample5/part-00096
# sample5/part-00175
# sample5/.part-00161.crc
# sample5/part-00201
# sample5/.part-00039.crc
# sample5/.part-00094.crc
# sample5/.part-00045.crc
# sample5/part-00092
# sample5/part-00106
# sample5/part-00171
# sample5/.part-00144.crc
# sample5/.part-00195.crc
# sample5/part-00098
# sample5/part-00076
# sample5/part-00001
# sample5/part-00195
# sample5/.part-00060.crc
# sample5/.part-00138.crc
# sample5/.part-00067.crc
# sample5/.part-00143.crc
# sample5/.part-00192.crc
# sample5/part-00143
# sample5/part-00134
# sample5/.part-00069.crc
# sample5/part-00039
# sample5/.part-00131.crc
# sample5/.part-00015.crc
# sample5/part-00149
# sample5/part-00033
# sample5/part-00044
# sample5/.part-00012.crc
# sample5/.part-00136.crc
# sample5/.part-00027.crc
# sample5/part-00065
# sample5/part-00012
# sample5/part-00186
# sample5/part-00168
# sample5/part-00018
# sample5/part-00081
# sample5/part-00115
# sample5/part-00162
# sample5/.part-00103.crc
# sample5/.part-00104.crc
# sample5/.part-00020.crc
# sample5/.part-00178.crc
# sample5/.part-00052.crc
# sample5/part-00020
# sample5/part-00057
# sample5/.part-00083.crc
# sample5/.part-00176.crc
# sample6/part-00179
# sample6/part-00197
# sample6/part-00003
# sample6/part-00074
# sample6/.part-00123.crc
# sample6/.part-00007.crc
# sample6/part-00173
# sample6/part-00104
# sample6/part-00090
# sample6/part-00009
# sample6/.part-00000.crc
# sample6/.part-00158.crc
# sample6/.part-00189.crc
# sample6/.part-00124.crc
# sample6/.part-00156.crc
# sample6/.part-00187.crc
# sample6/part-00046
# sample6/part-00031
# sample6/part-00136
# sample6/part-00141
# sample6/.part-00072.crc
# sample6/.part-00075.crc
# sample6/.part-00009.crc
# sample6/.part-00151.crc
# sample6/.part-00180.crc
# sample6/.part-00064.crc
# sample6/.part-00191.crc
# sample6/.part-00140.crc
# sample6/.part-00018.crc
# sample6/.part-00196.crc
# sample6/.part-00147.crc
# sample6/part-00036
# sample6/part-00041
# sample6/part-00146
# sample6/part-00131
# sample6/.part-00063.crc
# sample6/.part-00198.crc
# sample6/.part-00149.crc
# sample6/.part-00011.crc
# sample6/part-00200
# sample6/.part-00135.crc
# sample6/part-00073
# sample6/part-00004
# sample6/part-00190
# sample6/part-00109
# sample6/.part-00132.crc
# sample6/.part-00016.crc
# sample6/part-00079
# sample6/part-00097
# sample6/part-00103
# sample6/part-00174
# sample6/.part-00107.crc
# sample6/.part-00023.crc
# sample6/part-00155
# sample6/part-00122
# sample6/.part-00024.crc
# sample6/part-00058
# sample6/.part-00100.crc
# sample6/part-00128
# sample6/part-00025
# sample6/part-00052
# sample6/.part-00089.crc
# sample6/.part-00058.crc
# sample6/.part-00172.crc
# sample6/.part-00087.crc
# sample6/.part-00056.crc
# sample6/part-00084
# sample6/part-00110
# sample6/part-00167
# sample6/part-00189
# sample6/.part-00109.crc
# sample6/.part-00080.crc
# sample6/.part-00051.crc
# sample6/.part-00175.crc
# sample6/part-00060
# sample6/part-00017
# sample6/part-00183

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator

# Initialize Spark session with increased driver memory
spark = SparkSession.builder \
    .appName("ThemedPlaylists") \
    .config("spark.driver.memory", "8g") \
    .config("spark.executor.memory", "8g") \
    .config("spark.memory.offHeap.enabled", "true") \
    .config("spark.memory.offHeap.size", "8g") \
    .getOrCreate()

# Load the data
data_path = 'spotify-charts-all-audio-data/merged_data.csv'
df = spark.read.csv(data_path, header=True, inferSchema=True)

# Audio features
audio_features = [
    'af_danceability', 'af_energy', 'af_key', 'af_loudness', 'af_mode', 'af_speechiness',
    'af_acousticness', 'af_instrumentalness', 'af_liveness', 'af_valence', 'af_tempo', 'af_time_signature'
]

# Handle missing values and cast columns to float
for feature in audio_features:
    mean_value = df.select(avg(col(feature))).first()[0]
    df = df.fillna({feature: mean_value})
    df = df.withColumn(feature, col(feature).cast('float'))

df = df.dropna()

# Assemble features into a single vector
assembler = VectorAssembler(inputCols=audio_features, outputCol="features")
df = assembler.transform(df)

# Scale the features
scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures")
scaler_model = scaler.fit(df)
df = scaler_model.transform(df)

# Apply KMeans clustering with fewer clusters
kmeans = KMeans(featuresCol="scaledFeatures", k=5, seed=1)
model = kmeans.fit(df)

# Make predictions
df = model.transform(df)

# Evaluate clustering by computing Silhouette score
evaluator = ClusteringEvaluator(featuresCol="scaledFeatures")
silhouette = evaluator.evaluate(df)
print(f"Silhouette with squared euclidean distance = {silhouette}")

# Show cluster centers
centers = model.clusterCenters()
print("Cluster Centers: ")
for center in centers:
    print(center)

# Collect playlists to Pandas DataFrame and show
for i in range(5):
    cluster_df = df.where(col("prediction") == i).select("title", "artist", "album", "prediction")
    cluster_pd = cluster_df.toPandas()
    print(f"Cluster {i} Playlists:")
    print(cluster_pd.head(10))

# Stop Spark session
spark.stop()
# Out:
# Silhouette with squared euclidean distance = 0.16885429299529606
# Cluster Centers:
# [ 5.47011269  3.49793898  1.37145789 -3.04357328  1.07154114  1.3472644
#   0.99412344  0.06814212  1.21903852  1.91856358  3.77118663 15.44792057]
# [ 5.50135181  4.66303427  1.58398832 -1.93018009  1.03298437  0.84193001
#   0.66266788  0.02820836  1.41338169  2.99662488  3.67724962 15.39549266]
# [ 4.75271237  4.43002477  1.37688427 -2.19391194  1.28819587  1.65913045
#   0.73781029  0.05021336  1.35293092  2.49929803  5.5283471  15.42801401]
# [ 4.00029816  2.52478054  1.48641273 -3.6487289   1.52965503  0.57153457
#   2.60055508  0.05798193  1.22499037  1.56891535  3.96708374 14.53305287]
# [ 4.92755044  3.51957468  1.43562867 -3.92104058  0.90711358  0.85474231
#   1.28461213  9.18400464  1.35868732  1.81007569  4.07287869 15.2322508 ]
# Cluster 0 Playlists:
#                                                title  \
# 0                                          One Dance
# 1  Cuatro Babys (feat. Trap Capos, Noriel, Bryant...
# 2                                   Don't Wanna Know
# 3                                In the Name of Love
# 4                                               Work
# 5                                             Closer
# 6                                     Me Ama Me Odia
# 7         We Don't Talk Anymore (feat. Selena Gomez)
# 8  Diles (feat. Arcangel, Nengo Flow, Dj Luian & ...
# 9                                        Ruleta Rusa
#
#                                   artist  \
# 0                    Drake, WizKid, Kyla
# 1                                 Maluma
# 2               Maroon 5, Kendrick Lamar
# 3              Martin Garrix, Bebe Rexha
# 4                         Rihanna, Drake
# 5               The Chainsmokers, Halsey
# 6              Ozuna, Cosculluela, Revol
# 7                           Charlie Puth
# 8  Ozuna, Bad Bunny, Farruko, Ñengo Flow
# 9                           Kevin Roldan
#
#                                                album  prediction
# 0                                              Views           0
# 1  Cuatro Babys (feat. Trap Capos, Noriel, Bryant...           0
# 2                                   Don't Wanna Know           0
# 3                       The Martin Garrix Collection           0
# 4                                      ANTI (Deluxe)           0
# 5                                             Closer           0
# 6                                     Me Ama Me Odia           0
# 7                                    Nine Track Mind           0
# 8                                              Diles           0
# 9                                      The Beginning           0
# Cluster 1 Playlists:
#                               title                       artist  \
# 0           Chantaje (feat. Maluma)                      Shakira
# 1       Vente Pa' Ca (feat. Maluma)                 Ricky Martin
# 2        Reggaetón Lento (Bailemos)                         CNCO
# 3                       Shaky Shaky                 Daddy Yankee
# 4                       Traicionera              Sebastian Yatra
# 5         Otra vez (feat. J Balvin)                Zion & Lennox
# 6                Andas En Mi Cabeza  Chino & Nacho, Daddy Yankee
# 7    Desde Esa Noche (feat. Maluma)                       Thalia
# 8   Gyal You A Party Animal - Remix   Charly Black, Daddy Yankee
